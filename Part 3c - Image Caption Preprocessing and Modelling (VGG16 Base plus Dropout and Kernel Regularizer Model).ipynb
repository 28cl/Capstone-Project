# %% [markdown]
# # Part 3c - Image Caption Preprocessing and Modelling (VGG16 Base plus Dropout and Kernel Regularizer Model)

# %% [markdown]
# ## Mount Google Drive unto Colab Environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
# Check if in Colab Env
try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False

if IN_COLAB:
  print("We're running Colab")
# Out:
# We're running Colab

# %%
# Change Mount Location
if IN_COLAB:
  # Mount the Google Drive at mount
  mount='/content/drive/'
  print("Colab: mounting Google drive on ", mount)

  drive.mount(mount)

  # Switch to the directory on the Google Drive that you want to use
  import os
  drive_root = mount + "/My Drive/Colab Notebooks/Capstone/Code"
  
  # Create drive_root if it doesn't exist
  create_drive_root = True
  if create_drive_root:
    print("\nColab: making sure ", drive_root, " exists.")
    os.makedirs(drive_root, exist_ok=True)
  
  # Change to the directory
  print("\nColab: Changing directory to ", drive_root)
  # %cd $drive_root
# Out:
# Colab: mounting Google drive on  /content/drive/
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
#
# Colab: making sure  /content/drive//My Drive/Colab Notebooks/Capstone/Code  exists.
#
# Colab: Changing directory to  /content/drive//My Drive/Colab Notebooks/Capstone/Code
# /content/drive/My Drive/Colab Notebooks/Capstone/Code

# %%
# GPU
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 11619432745235797
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 40231960576
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 13346782092006154878
#  physical_device_desc: "device: 0, name: A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0"
#  xla_global_id: 416903419]

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
import pickle
import cloudpickle
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from collections import Counter 

# to explore text in captions data
import nltk
#nltk.download('stopwords')
import regex as re
from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS
from sklearn.feature_extraction.text import CountVectorizer

# to process the images
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# to process the text
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# for modelling
from tensorflow.keras.models import Model
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger

#utilities
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, add
from tensorflow.keras import regularizers

# %% [markdown]
# ## Set Directories

# %%
# set directories
BASE_DIR = mount + "/My Drive/Colab Notebooks/Capstone/Data/flickr8k"
WORKING_DIR = mount + "/My Drive/Colab Notebooks/Capstone/Code"

# %% [markdown]
# ## Load Features From Pickle

# %%
# load features from pickle
with open(os.path.join(WORKING_DIR, 'features_vgg16.pkl'), 'rb') as f:
    features = pickle.load(f)

# %% [markdown]
# ## Load Captions Data

# %%
with open(os.path.join(BASE_DIR, 'captions.txt'), 'r') as f:
    next(f)
    captions_doc = f.read()

# %% [markdown]
# ## Map Image to Captions

# %%
# create mapping of image to captions
mapping = {}
#process lines
for line in tqdm(captions_doc.split('\n')):
    #split the line by comma(,)
    tokens = line.split(',')
    if len(line) < 2:
        continue
    image_id, caption = tokens[0], tokens[1:]
    #remove extension from image ID
    image_id = image_id.split('.')[0]
    #convert caption list to string
    caption = ' '.join(caption)
    #create list if needed
    if image_id not in mapping:
        mapping[image_id] = []
    mapping[image_id].append(caption)
# Out:
#   0%|          | 0/40456 [00:00<?, ?it/s]

# %%
len(mapping)
# Out:
# 8091

# %% [markdown]
# ## Preprocess the Captions Data

# %%
def clean(mapping):
    for key, captions in mapping.items():
        for i in range(len(captions)):
            #take one caption at a time
            caption = captions[i]
            #preprocessing steps
            #convert to lowercase
            caption = caption.lower()
            #replace all digits, special characters, etc.
            caption = caption.replace('[^A-Za-z]', '')
            #delete additional spaces
            caption = caption.replace('\s+', ' ')
            #add start and end tags to captions
            caption = 'startseq ' + ' '.join([word for word in caption.split() if len(word)>1]) + ' endseq'
            captions[i] = caption

# %%
# before preprocessing of text
mapping['1000268201_693b08cb0e']
# Out:
# ['A child in a pink dress is climbing up a set of stairs in an entry way .',
#  'A girl going into a wooden building .',
#  'A little girl climbing into a wooden playhouse .',
#  'A little girl climbing the stairs to her playhouse .',
#  'A little girl in a pink dress going into a wooden cabin .']

# %%
#preprocess the text
clean(mapping)

# %%
#after preprocessing of text
mapping['1000268201_693b08cb0e']
# Out:
# ['startseq child in pink dress is climbing up set of stairs in an entry way endseq',
#  'startseq girl going into wooden building endseq',
#  'startseq little girl climbing into wooden playhouse endseq',
#  'startseq little girl climbing the stairs to her playhouse endseq',
#  'startseq little girl in pink dress going into wooden cabin endseq']

# %%
all_captions = []
for key in mapping:
    for caption in mapping[key]:
        all_captions.append(caption)

# %%
len(all_captions)
# Out:
# 40455

# %%
all_captions[:10]
# Out:
# ['startseq child in pink dress is climbing up set of stairs in an entry way endseq',
#  'startseq girl going into wooden building endseq',
#  'startseq little girl climbing into wooden playhouse endseq',
#  'startseq little girl climbing the stairs to her playhouse endseq',
#  'startseq little girl in pink dress going into wooden cabin endseq',
#  'startseq black dog and spotted dog are fighting endseq',
#  'startseq black dog and tri-colored dog playing with each other on the road endseq',
#  'startseq black dog and white dog with brown spots are staring at each other in the street endseq',
#  'startseq two dogs of different breeds looking at each other on the road endseq',
#  'startseq two dogs on pavement moving toward each other endseq']

# %%
# tokenize the text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(all_captions)
vocab_size = len(tokenizer.word_index) + 1 #index up to the greatest token ID

# %%
#number of unique words
vocab_size
# Out:
# 8485

# %%
# get maximum length of caption available
max_length = max(len(caption.split()) for caption in all_captions)
max_length
# Out:
# 35

# %% [markdown]
# ## Train/Test Split

# %%
import random

image_ids = list(mapping.keys())
print(len(image_ids))
# Out:
# 8091

# %%
train = random.sample(image_ids, 6091)
test = random.sample(image_ids, 1000)
val = random.sample(image_ids, 1000)

# %%
print(len(train))
print(len(val))
print(len(test))
# Out:
# 6091
# 1000
# 1000

# %% [markdown]
# ## Create Data Generation Function

# %%
# create data generator to get data in batches (avoid session crashing)

# startseq girl going into wooden building endseq
#        X                   y
# startseq                   girl
# startseq girl              going
# startseq girl going        into
# ...........
# startseq girl going into wooden building      endseq

def data_generator(data_keys, mapping, features, tokenizer, max_length, vocab_size, batch_size):
    #loop over images
    X1, X2, y = list(), list(), list()
    n = 0
    while 1:
        for key in data_keys:
            n += 1
            captions = mapping[key]
            #process each caption
            for caption in captions:
                #encode the sequence
                seq = tokenizer.texts_to_sequences([caption])[0]
                # split the sequence into X, y pairs
                for i in range(1, len(seq)):
                    #split into input and output pairs
                    in_seq, out_seq = seq[:i], seq[i]
                    # pad input sequence for common length
                    in_seq = pad_sequences([in_seq], maxlen = max_length)[0]
                    # encode output sequence (like one hot encoding)
                    out_seq = to_categorical([out_seq], num_classes = vocab_size)[0]
                    
                    #store the sequences
                    X1.append(features[key][0])
                    X2.append(in_seq)
                    y.append(out_seq)
                    
            if n == batch_size:
                X1, X2, y = np.array(X1), np.array(X2), np.array(y)
                yield [X1, X2], y
                X1, X2, y = list(), list(), list()
                n = 0

# %% [markdown]
# ## Model Creation - CNN LSTM (Base plus Dropout and Regularization Model)

# %%
# encoder model
# image feature layers
inputs1 = Input(shape = (4096,))
fe1 = Dropout(0.6)(inputs1) #increase dropout to 0.6 to avoid overfitting
fe2 = Dense(256, activation = 'relu', kernel_regularizer = regularizers.l2(l=0.01))(fe1)

#sequence feature layers
inputs2 = Input(shape=(max_length,))
se1 = Embedding(vocab_size, 256, mask_zero = True)(inputs2)
se2 = Dropout(0.6)(se1) #increase dropout 0.6 to avoid overfitting
se3 = LSTM(256)(se2)

#decoder model
decoder1 = add([fe2, se3])
decoder2 = Dense(256, activation = 'relu', kernel_regularizer = regularizers.l2(l=0.01))(decoder1)
outputs = Dense(vocab_size, activation = 'softmax')(decoder2)

final_model = Model(inputs=[inputs1, inputs2], outputs = outputs)

# plot the model
plot_model(final_model, show_shapes = True)

# %%
final_model.summary()
# Out:
# Model: "model_13"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_33 (InputLayer)          [(None, 35)]         0           []
#
#  input_32 (InputLayer)          [(None, 4096)]       0           []
#
#  embedding_13 (Embedding)       (None, 35, 256)      2172160     ['input_33[0][0]']
#
#  dropout_31 (Dropout)           (None, 4096)         0           ['input_32[0][0]']
#
#  dropout_32 (Dropout)           (None, 35, 256)      0           ['embedding_13[0][0]']
#
#  dense_39 (Dense)               (None, 256)          1048832     ['dropout_31[0][0]']
#
#  lstm_13 (LSTM)                 (None, 256)          525312      ['dropout_32[0][0]']
#
#  add_13 (Add)                   (None, 256)          0           ['dense_39[0][0]',
#                                                                   'lstm_13[0][0]']
#
#  dense_40 (Dense)               (None, 256)          65792       ['add_13[0][0]']
#
#  dense_41 (Dense)               (None, 8485)         2180645     ['dense_40[0][0]']
#
# ==================================================================================================
# Total params: 5,992,741
# Trainable params: 5,992,741
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
#Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
final_model.compile(loss = 'categorical_crossentropy', optimizer = opt, metrics=['accuracy'])

# %%
# Train the model
epochs = 300
batch_size = 32
steps = len(train) // batch_size
val_steps = len(test) // batch_size

#Interrupts training when improvement stops and monitor the model's val acc
#Interrupts training when accuracy nas stopped improving for more than 5 epochs.
callbacks_list = tf.keras.callbacks.EarlyStopping(monitor = 'accuracy', patience = 5,)

#save results of model fit in a CSV file
csv_log = CSVLogger("base_vgg_dropout_kernel_regularizer_results.csv")

# create data generator
generator = data_generator(train, mapping, features, tokenizer, max_length, vocab_size, batch_size)
val_generator = data_generator(val, mapping, features, tokenizer, max_length, vocab_size, batch_size)
#fit for one epoch
history = final_model.fit(generator, epochs = epochs, steps_per_epoch = steps, validation_data=val_generator, callbacks=(callbacks_list, csv_log), validation_steps=val_steps, verbose  = 1)
# Out:
# Epoch 1/300
# 190/190 [==============================] - 34s 155ms/step - loss: 6.8574 - accuracy: 0.1275 - val_loss: 5.1082 - val_accuracy: 0.1753
# Epoch 2/300
# 190/190 [==============================] - 28s 148ms/step - loss: 4.7429 - accuracy: 0.2067 - val_loss: 4.3784 - val_accuracy: 0.2394
# Epoch 3/300
# 190/190 [==============================] - 28s 148ms/step - loss: 4.3158 - accuracy: 0.2451 - val_loss: 4.1453 - val_accuracy: 0.2662
# Epoch 4/300
# 190/190 [==============================] - 28s 149ms/step - loss: 4.1151 - accuracy: 0.2613 - val_loss: 4.0222 - val_accuracy: 0.2758
# Epoch 5/300
# 190/190 [==============================] - 28s 149ms/step - loss: 3.9852 - accuracy: 0.2702 - val_loss: 3.9505 - val_accuracy: 0.2818
# Epoch 6/300
# 190/190 [==============================] - 28s 150ms/step - loss: 3.8881 - accuracy: 0.2779 - val_loss: 3.8894 - val_accuracy: 0.2884
# Epoch 7/300
# 190/190 [==============================] - 28s 149ms/step - loss: 3.8115 - accuracy: 0.2834 - val_loss: 3.8348 - val_accuracy: 0.2923
# Epoch 8/300
# 190/190 [==============================] - 28s 148ms/step - loss: 3.7409 - accuracy: 0.2896 - val_loss: 3.7965 - val_accuracy: 0.2973
# Epoch 9/300
# 190/190 [==============================] - 28s 148ms/step - loss: 3.6819 - accuracy: 0.2942 - val_loss: 3.7585 - val_accuracy: 0.3002
# Epoch 10/300
# 190/190 [==============================] - 28s 149ms/step - loss: 3.6357 - accuracy: 0.2991 - val_loss: 3.7310 - val_accuracy: 0.3041
# Epoch 11/300
# 190/190 [==============================] - 28s 149ms/step - loss: 3.5903 - accuracy: 0.3018 - val_loss: 3.7021 - val_accuracy: 0.3065
# Epoch 12/300
# 190/190 [==============================] - 28s 149ms/step - loss: 3.5518 - accuracy: 0.3057 - val_loss: 3.6647 - val_accuracy: 0.3102
# Epoch 13/300
# 190/190 [==============================] - 28s 150ms/step - loss: 3.5128 - accuracy: 0.3089 - val_loss: 3.6245 - val_accuracy: 0.3141
# Epoch 14/300
# 190/190 [==============================] - 28s 150ms/step - loss: 3.4854 - accuracy: 0.3120 - val_loss: 3.6170 - val_accuracy: 0.3159
# Epoch 15/300
# 190/190 [==============================] - 28s 149ms/step - loss: 3.4501 - accuracy: 0.3158 - val_loss: 3.5874 - val_accuracy: 0.3182
# Epoch 16/300
# 190/190 [==============================] - 29s 150ms/step - loss: 3.4227 - accuracy: 0.3186 - val_loss: 3.5737 - val_accuracy: 0.3209
# Epoch 17/300
# 190/190 [==============================] - 29s 150ms/step - loss: 3.4005 - accuracy: 0.3212 - val_loss: 3.5299 - val_accuracy: 0.3269
# Epoch 18/300
# 190/190 [==============================] - 29s 150ms/step - loss: 3.3674 - accuracy: 0.3244 - val_loss: 3.5068 - val_accuracy: 0.3293
# Epoch 19/300
# 190/190 [==============================] - 28s 150ms/step - loss: 3.3369 - accuracy: 0.3270 - val_loss: 3.4985 - val_accuracy: 0.3306
# Epoch 20/300
# 190/190 [==============================] - 28s 149ms/step - loss: 3.3186 - accuracy: 0.3288 - val_loss: 3.4887 - val_accuracy: 0.3316
# Epoch 21/300
# 190/190 [==============================] - 29s 152ms/step - loss: 3.3004 - accuracy: 0.3317 - val_loss: 3.4828 - val_accuracy: 0.3334
# Epoch 22/300
# 190/190 [==============================] - 29s 150ms/step - loss: 3.2883 - accuracy: 0.3339 - val_loss: 3.4486 - val_accuracy: 0.3354
# Epoch 23/300
# 190/190 [==============================] - 28s 149ms/step - loss: 3.2641 - accuracy: 0.3363 - val_loss: 3.4579 - val_accuracy: 0.3366
# Epoch 24/300
# 190/190 [==============================] - 28s 150ms/step - loss: 3.2452 - accuracy: 0.3384 - val_loss: 3.4299 - val_accuracy: 0.3393
# Epoch 25/300
# 190/190 [==============================] - 29s 151ms/step - loss: 3.2245 - accuracy: 0.3406 - val_loss: 3.4155 - val_accuracy: 0.3401
# Epoch 26/300
# 190/190 [==============================] - 29s 151ms/step - loss: 3.2151 - accuracy: 0.3419 - val_loss: 3.4349 - val_accuracy: 0.3386
# Epoch 27/300
# 190/190 [==============================] - 28s 150ms/step - loss: 3.1913 - accuracy: 0.3448 - val_loss: 3.3981 - val_accuracy: 0.3444
# Epoch 28/300
# 190/190 [==============================] - 29s 151ms/step - loss: 3.1899 - accuracy: 0.3457 - val_loss: 3.4378 - val_accuracy: 0.3383
# Epoch 29/300
# 190/190 [==============================] - 29s 150ms/step - loss: 3.1630 - accuracy: 0.3479 - val_loss: 3.4264 - val_accuracy: 0.3393
# Epoch 30/300
# 190/190 [==============================] - 28s 150ms/step - loss: 3.1657 - accuracy: 0.3467 - val_loss: 3.3820 - val_accuracy: 0.3436
# Epoch 31/300
# 190/190 [==============================] - 29s 150ms/step - loss: 3.1432 - accuracy: 0.3502 - val_loss: 3.3766 - val_accuracy: 0.3455
# Epoch 32/300
# 190/190 [==============================] - 29s 151ms/step - loss: 3.1427 - accuracy: 0.3498 - val_loss: 3.3700 - val_accuracy: 0.3442
# Epoch 33/300
# 190/190 [==============================] - 29s 150ms/step - loss: 3.1181 - accuracy: 0.3537 - val_loss: 3.3396 - val_accuracy: 0.3468
# Epoch 34/300
# 190/190 [==============================] - 29s 151ms/step - loss: 3.1036 - accuracy: 0.3558 - val_loss: 3.3631 - val_accuracy: 0.3478
# Epoch 35/300
# 190/190 [==============================] - 28s 150ms/step - loss: 3.0983 - accuracy: 0.3561 - val_loss: 3.3835 - val_accuracy: 0.3457
# Epoch 36/300
# 190/190 [==============================] - 29s 150ms/step - loss: 3.0973 - accuracy: 0.3560 - val_loss: 3.3387 - val_accuracy: 0.3509
# Epoch 37/300
# 190/190 [==============================] - 28s 149ms/step - loss: 3.0750 - accuracy: 0.3592 - val_loss: 3.3500 - val_accuracy: 0.3500
# Epoch 38/300
# 190/190 [==============================] - 29s 151ms/step - loss: 3.0769 - accuracy: 0.3593 - val_loss: 3.3389 - val_accuracy: 0.3501
# Epoch 39/300
# 190/190 [==============================] - 28s 149ms/step - loss: 3.0593 - accuracy: 0.3612 - val_loss: 3.3049 - val_accuracy: 0.3543
# Epoch 40/300
# 190/190 [==============================] - 28s 150ms/step - loss: 3.0383 - accuracy: 0.3635 - val_loss: 3.2870 - val_accuracy: 0.3571
# Epoch 41/300
# 190/190 [==============================] - 29s 151ms/step - loss: 3.0252 - accuracy: 0.3658 - val_loss: 3.3434 - val_accuracy: 0.3511
# Epoch 42/300
# 190/190 [==============================] - 29s 152ms/step - loss: 3.0292 - accuracy: 0.3657 - val_loss: 3.2993 - val_accuracy: 0.3542
# Epoch 43/300
# 190/190 [==============================] - 28s 149ms/step - loss: 3.0158 - accuracy: 0.3672 - val_loss: 3.2980 - val_accuracy: 0.3560
# Epoch 44/300
# 190/190 [==============================] - 29s 151ms/step - loss: 3.0152 - accuracy: 0.3669 - val_loss: 3.2974 - val_accuracy: 0.3540
# Epoch 45/300
# 190/190 [==============================] - 29s 152ms/step - loss: 3.0071 - accuracy: 0.3687 - val_loss: 3.2671 - val_accuracy: 0.3572
# Epoch 46/300
# 190/190 [==============================] - 28s 149ms/step - loss: 2.9777 - accuracy: 0.3727 - val_loss: 3.2707 - val_accuracy: 0.3591
# Epoch 47/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.9760 - accuracy: 0.3723 - val_loss: 3.2904 - val_accuracy: 0.3588
# Epoch 48/300
# 190/190 [==============================] - 29s 150ms/step - loss: 2.9615 - accuracy: 0.3737 - val_loss: 3.2676 - val_accuracy: 0.3608
# Epoch 49/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.9623 - accuracy: 0.3738 - val_loss: 3.2646 - val_accuracy: 0.3597
# Epoch 50/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.9609 - accuracy: 0.3741 - val_loss: 3.2443 - val_accuracy: 0.3637
# Epoch 51/300
# 190/190 [==============================] - 28s 150ms/step - loss: 2.9412 - accuracy: 0.3763 - val_loss: 3.2564 - val_accuracy: 0.3646
# Epoch 52/300
# 190/190 [==============================] - 28s 149ms/step - loss: 2.9410 - accuracy: 0.3771 - val_loss: 3.2395 - val_accuracy: 0.3654
# Epoch 53/300
# 190/190 [==============================] - 29s 150ms/step - loss: 2.9213 - accuracy: 0.3797 - val_loss: 3.2343 - val_accuracy: 0.3671
# Epoch 54/300
# 190/190 [==============================] - 29s 150ms/step - loss: 2.9240 - accuracy: 0.3793 - val_loss: 3.2499 - val_accuracy: 0.3658
# Epoch 55/300
# 190/190 [==============================] - 28s 150ms/step - loss: 2.9093 - accuracy: 0.3809 - val_loss: 3.2614 - val_accuracy: 0.3647
# Epoch 56/300
# 190/190 [==============================] - 29s 150ms/step - loss: 2.9072 - accuracy: 0.3815 - val_loss: 3.2270 - val_accuracy: 0.3690
# Epoch 57/300
# 190/190 [==============================] - 28s 150ms/step - loss: 2.8937 - accuracy: 0.3830 - val_loss: 3.2070 - val_accuracy: 0.3699
# Epoch 58/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.8757 - accuracy: 0.3849 - val_loss: 3.2376 - val_accuracy: 0.3658
# Epoch 59/300
# 190/190 [==============================] - 29s 150ms/step - loss: 2.8750 - accuracy: 0.3852 - val_loss: 3.2425 - val_accuracy: 0.3669
# Epoch 60/300
# 190/190 [==============================] - 29s 150ms/step - loss: 2.8659 - accuracy: 0.3865 - val_loss: 3.2210 - val_accuracy: 0.3690
# Epoch 61/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.8625 - accuracy: 0.3875 - val_loss: 3.2267 - val_accuracy: 0.3681
# Epoch 62/300
# 190/190 [==============================] - 29s 152ms/step - loss: 2.8554 - accuracy: 0.3874 - val_loss: 3.2311 - val_accuracy: 0.3678
# Epoch 63/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.8545 - accuracy: 0.3882 - val_loss: 3.2293 - val_accuracy: 0.3702
# Epoch 64/300
# 190/190 [==============================] - 28s 150ms/step - loss: 2.8574 - accuracy: 0.3879 - val_loss: 3.2116 - val_accuracy: 0.3716
# Epoch 65/300
# 190/190 [==============================] - 28s 150ms/step - loss: 2.8423 - accuracy: 0.3903 - val_loss: 3.2434 - val_accuracy: 0.3702
# Epoch 66/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.8459 - accuracy: 0.3896 - val_loss: 3.2478 - val_accuracy: 0.3688
# Epoch 67/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.8327 - accuracy: 0.3918 - val_loss: 3.2433 - val_accuracy: 0.3719
# Epoch 68/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.8229 - accuracy: 0.3927 - val_loss: 3.2410 - val_accuracy: 0.3707
# Epoch 69/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.8204 - accuracy: 0.3934 - val_loss: 3.2145 - val_accuracy: 0.3726
# Epoch 70/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.8169 - accuracy: 0.3928 - val_loss: 3.2543 - val_accuracy: 0.3711
# Epoch 71/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.8082 - accuracy: 0.3947 - val_loss: 3.2121 - val_accuracy: 0.3761
# Epoch 72/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.8053 - accuracy: 0.3950 - val_loss: 3.2819 - val_accuracy: 0.3684
# Epoch 73/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.8029 - accuracy: 0.3951 - val_loss: 3.2271 - val_accuracy: 0.3734
# Epoch 74/300
# 190/190 [==============================] - 28s 150ms/step - loss: 2.7989 - accuracy: 0.3960 - val_loss: 3.1896 - val_accuracy: 0.3756
# Epoch 75/300
# 190/190 [==============================] - 28s 150ms/step - loss: 2.7977 - accuracy: 0.3962 - val_loss: 3.1839 - val_accuracy: 0.3773
# Epoch 76/300
# 190/190 [==============================] - 29s 150ms/step - loss: 2.7883 - accuracy: 0.3972 - val_loss: 3.1947 - val_accuracy: 0.3760
# Epoch 77/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.7885 - accuracy: 0.3978 - val_loss: 3.2183 - val_accuracy: 0.3749
# Epoch 78/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.7746 - accuracy: 0.3986 - val_loss: 3.2087 - val_accuracy: 0.3769
# Epoch 79/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.7753 - accuracy: 0.3996 - val_loss: 3.1847 - val_accuracy: 0.3787
# Epoch 80/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.7760 - accuracy: 0.3984 - val_loss: 3.1382 - val_accuracy: 0.3815
# Epoch 81/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.7610 - accuracy: 0.4010 - val_loss: 3.1442 - val_accuracy: 0.3825
# Epoch 82/300
# 190/190 [==============================] - 29s 152ms/step - loss: 2.7556 - accuracy: 0.4019 - val_loss: 3.1727 - val_accuracy: 0.3798
# Epoch 83/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.7588 - accuracy: 0.4009 - val_loss: 3.2182 - val_accuracy: 0.3770
# Epoch 84/300
# 190/190 [==============================] - 29s 150ms/step - loss: 2.7576 - accuracy: 0.4015 - val_loss: 3.1993 - val_accuracy: 0.3786
# Epoch 85/300
# 190/190 [==============================] - 28s 149ms/step - loss: 2.7525 - accuracy: 0.4021 - val_loss: 3.1683 - val_accuracy: 0.3815
# Epoch 86/300
# 190/190 [==============================] - 28s 150ms/step - loss: 2.7471 - accuracy: 0.4027 - val_loss: 3.1744 - val_accuracy: 0.3810
# Epoch 87/300
# 190/190 [==============================] - 29s 150ms/step - loss: 2.7489 - accuracy: 0.4032 - val_loss: 3.1972 - val_accuracy: 0.3796
# Epoch 88/300
# 190/190 [==============================] - 28s 149ms/step - loss: 2.7280 - accuracy: 0.4054 - val_loss: 3.2060 - val_accuracy: 0.3797
# Epoch 89/300
# 190/190 [==============================] - 28s 149ms/step - loss: 2.7322 - accuracy: 0.4052 - val_loss: 3.1284 - val_accuracy: 0.3868
# Epoch 90/300
# 190/190 [==============================] - 28s 149ms/step - loss: 2.7246 - accuracy: 0.4063 - val_loss: 3.1219 - val_accuracy: 0.3888
# Epoch 91/300
# 190/190 [==============================] - 28s 150ms/step - loss: 2.7268 - accuracy: 0.4055 - val_loss: 3.1330 - val_accuracy: 0.3863
# Epoch 92/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.7209 - accuracy: 0.4066 - val_loss: 3.1319 - val_accuracy: 0.3868
# Epoch 93/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.7166 - accuracy: 0.4073 - val_loss: 3.1343 - val_accuracy: 0.3879
# Epoch 94/300
# 190/190 [==============================] - 28s 150ms/step - loss: 2.7149 - accuracy: 0.4075 - val_loss: 3.1217 - val_accuracy: 0.3884
# Epoch 95/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.7040 - accuracy: 0.4092 - val_loss: 3.1029 - val_accuracy: 0.3914
# Epoch 96/300
# 190/190 [==============================] - 28s 149ms/step - loss: 2.7004 - accuracy: 0.4083 - val_loss: 3.1022 - val_accuracy: 0.3893
# Epoch 97/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.7075 - accuracy: 0.4086 - val_loss: 3.1015 - val_accuracy: 0.3907
# Epoch 98/300
# 190/190 [==============================] - 29s 150ms/step - loss: 2.6931 - accuracy: 0.4111 - val_loss: 3.1337 - val_accuracy: 0.3886
# Epoch 99/300
# 190/190 [==============================] - 28s 150ms/step - loss: 2.6841 - accuracy: 0.4120 - val_loss: 3.1237 - val_accuracy: 0.3901
# Epoch 100/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.6844 - accuracy: 0.4118 - val_loss: 3.1300 - val_accuracy: 0.3880
# Epoch 101/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.6826 - accuracy: 0.4124 - val_loss: 3.1489 - val_accuracy: 0.3835
# Epoch 102/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.6870 - accuracy: 0.4118 - val_loss: 3.1228 - val_accuracy: 0.3883
# Epoch 103/300
# 190/190 [==============================] - 29s 151ms/step - loss: 2.6779 - accuracy: 0.4131 - val_loss: 3.0998 - val_accuracy: 0.3921
# Epoch 104/300
# 190/190 [==============================] - 28s 150ms/step - loss: 2.6657 - accuracy: 0.4148 - val_loss: 3.1319 - val_accuracy: 0.3860
# Epoch 105/300
# 190/190 [==============================] - 28s 150ms/step - loss: 2.6712 - accuracy: 0.4141 - val_loss: 3.1475 - val_accuracy: 0.3851
# Epoch 106/300
# 190/190 [==============================] - 28s 150ms/step - loss: 2.6764 - accuracy: 0.4135 - val_loss: 3.1513 - val_accuracy: 0.3858
# Epoch 107/300
# 190/190 [==============================] - 28s 150ms/step - loss: 2.6662 - accuracy: 0.4148 - val_loss: 3.0946 - val_accuracy: 0.3911
# Epoch 108/300
# 190/190 [==============================] - 28s 150ms/step - loss: 2.6779 - accuracy: 0.4133 - val_loss: 3.1597 - val_accuracy: 0.3866
# Epoch 109/300
# 190/190 [==============================] - 28s 149ms/step - loss: 2.6749 - accuracy: 0.4139 - val_loss: 3.1276 - val_accuracy: 0.3897

# %%
# save the model
final_model.save(WORKING_DIR + '/base_val_vgg_dropout_kernel_regularizer_model.h5')

# %% [markdown]
# ### Visualizing Model Accuracy and Loss

# %%
#load CSV file
data = pd.read_csv(mount + "/My Drive/Colab Notebooks/Capstone/Code/base_vgg_dropout_kernel_regularizer_results.csv")
data.head()
# Out:
#    epoch  accuracy      loss  val_accuracy  val_loss
# 0      0  0.127545  6.857379      0.175295  5.108199
# 1      1  0.206704  4.742885      0.239356  4.378357
# 2      2  0.245069  4.315808      0.266208  4.145251
# 3      3  0.261341  4.115085      0.275830  4.022213
# 4      4  0.270171  3.985247      0.281762  3.950500

# %%
# Plot Training/Val Accuracy by Epoch for Base VGG16 with Dropout and Kernel Regularizer Model
plt.title('Train/Val Acc by Epoch (Base VGG16 + Dropout and Kernel Regularizer Model)', fontsize = 25)
plt.plot(data['accuracy'], color='blue', label='accuracy')
plt.plot(data['val_accuracy'], color='red', label='val_accuracy')
plt.xlabel('Epoch', fontsize = 18)
plt.ylabel('Categorical Crossentropy', fontsize = 18)
plt.rcParams["figure.figsize"] = (12,8)
plt.legend()
plt.show()

# %%
# Plot Training/Val Accuracy/Loss by Epoch for Base VGG16 with Dropout and Kernel Regularizer Model
plt.title('Train/Val Loss by Epoch (Base VGG16 + Dropout and Kernel Regularizer Model)', fontsize = 25)
plt.plot(data['loss'], color='orange', label='loss')
plt.plot(data['val_loss'], color='green', label='val_loss')
plt.xlabel('Epoch', fontsize = 18)
plt.ylabel('Categorical Crossentropy', fontsize = 18)
plt.rcParams["figure.figsize"] = (12,8)
plt.legend()
plt.show()

# %% [markdown]
# ## Generate Captions for Images

# %%
def idx_to_word(integer, tokenizer):
    for word, index in tokenizer.word_index.items():
        if index == integer:
            return word
    return None

# %%
# generate caption for an image
def predict_caption(model, image, tokenizer, max_length):
    #add start tag for generation process
    in_text = 'startseq'
    #iterate over the max length of sequence
    for i in range(max_length):
        #encode input sequence
        sequence = tokenizer.texts_to_sequences([in_text])[0]
        #pad the sequence
        sequence = pad_sequences([sequence], max_length)
        #predict next word
        yhat = final_model.predict([image, sequence], verbose = 0)
        #get index with high probability
        yhat= np.argmax(yhat)
        #convert index to word
        word = idx_to_word(yhat, tokenizer)
        #stop if word not found
        if word is None:
            break
        #append word as input for generation next word
        in_text += ' ' + word
        #stop if we reach end tag
        if word == 'endseq':
            break
    return in_text

# %% [markdown]
# ### BLEU Score

# %%
from nltk.translate.bleu_score import corpus_bleu

# %%
# validate with test data
actual, predicted = list(), list()

for key in tqdm(test):
    #get actual caption
    captions = mapping[key]
    #predict the caption for image
    y_pred = predict_caption(final_model, features[key], tokenizer, max_length)
    #split into words  
    actual_captions = [caption.split() for caption in captions]
    y_pred = y_pred.split()
    #append to the list
    actual.append(actual_captions)
    predicted.append(y_pred)
    
#calculate BLEU Score
print("BLEU-1: %f" % corpus_bleu(actual, predicted, weights = (1.0, 0, 0, 0)))
print("BLEU-2: %f" % corpus_bleu(actual, predicted, weights = (0.5, 0.5, 0, 0)))
print("BLEU-3: %f" % corpus_bleu(actual, predicted, weights = (0.3, 0.3, 0.3, 0.1)))
print("BLEU-4: %f" % corpus_bleu(actual, predicted, weights = (0.25, 0.25, 0.25, 0.25)))
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# BLEU-1: 0.575397
# BLEU-2: 0.345768
# BLEU-3: 0.179862
# BLEU-4: 0.133144

# %% [markdown]
# ## Visualize the Results of Image Captions

# %%
from PIL import Image
import matplotlib.pyplot as plt

def generate_caption(image_name):
    #load the image
    image_id = image_name.split('.')[0]
    img_path = os.path.join(BASE_DIR, "Images", image_name)
    image = Image.open(img_path)
    captions = mapping[image_id]
    print('-----------Actual-----------')
    for caption in captions:
        print(caption)

    #predict the caption
    y_pred = predict_caption(final_model, features[image_id], tokenizer, max_length)
    print('-----------Predicted-----------')
    print(y_pred)
    plt.imshow(image)

# %%
generate_caption("421808539_57abee6d55.jpg")
# Out:
# -----------Actual-----------
# startseq brown dog walks through snow endseq
# startseq brown puppy walking through the snow endseq
# startseq dog looks curious at adventures lying ahead in the snow endseq
# startseq dog walking in the snow endseq
# startseq yellow puppy walking through the snow endseq
# -----------Predicted-----------
# startseq brown dog nibbles the snow of snow covered ground endseq

# %%
generate_caption("1193116658_c0161c35b5.jpg")
# Out:
# -----------Actual-----------
# startseq girl rides unicycle as another rides scooter next to her endseq
# startseq girl rides unicycle with child who rides scooter endseq
# startseq young girl rides unicycle next to another riding scooter on busy street endseq
# startseq the girl on the unicycle reaches out for the child on the scooter endseq
# startseq there is girl on unicycle and child on scooter endseq
# -----------Predicted-----------
# startseq woman in black and black skirt and black boots is riding bike endseq

# %%
generate_caption("1285067106_2adc307240.jpg")
# Out:
# -----------Actual-----------
# startseq boy in white plays baseball endseq
# startseq young boy is getting ready to through baseball endseq
# startseq little leaguer getting ready for pitch endseq
# startseq the boy is wearing white baseball uniform and holding baseball endseq
# startseq the young ohio baseball player contemplates his pitch endseq
# -----------Predicted-----------
# startseq man in white shirt and white shorts is running endseq

# %%
generate_caption("516725192_c9cdd63878.jpg")
# Out:
# -----------Actual-----------
# startseq fisherman stands on the beach on gray day endseq
# startseq man holding fishing pole and tackle box walking in from the ocean endseq
# startseq man in yellow cap is on the beach carrying fishing pole endseq
# startseq man with fishing pole standing on beach endseq
# startseq person is standing in the ocean fully clothed holding fishing pole in one hand and tackle box in the other endseq
# -----------Predicted-----------
# startseq man is surfing on the beach endseq
