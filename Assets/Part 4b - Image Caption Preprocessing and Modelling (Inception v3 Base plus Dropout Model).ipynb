# %% [markdown]
# # Part 4b - Image Caption Preprocessing and Modelling (Inception v3 Base plus Dropout Model)

# %% [markdown]
# ## Mount Google Drive unto Colab Environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content

# %%
# Check if in Colab Env
try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False

if IN_COLAB:
  print("We're running Colab")
# Out:
# We're running Colab

# %%
# Change Mount Location
if IN_COLAB:
  # Mount the Google Drive at mount
  mount='/content/drive/'
  print("Colab: mounting Google drive on ", mount)

  drive.mount(mount)

  # Switch to the directory on the Google Drive that you want to use
  import os
  drive_root = mount + "/My Drive/Colab Notebooks/Capstone/Code"
  
  # Create drive_root if it doesn't exist
  create_drive_root = True
  if create_drive_root:
    print("\nColab: making sure ", drive_root, " exists.")
    os.makedirs(drive_root, exist_ok=True)
  
  # Change to the directory
  print("\nColab: Changing directory to ", drive_root)
  # %cd $drive_root
# Out:
# Colab: mounting Google drive on  /content/drive/
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
#
# Colab: making sure  /content/drive//My Drive/Colab Notebooks/Capstone/Code  exists.
#
# Colab: Changing directory to  /content/drive//My Drive/Colab Notebooks/Capstone/Code
# /content/drive/My Drive/Colab Notebooks/Capstone/Code

# %%
# GPU
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 14815931568768442880
#  xla_global_id: -1, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 40231960576
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 9255001930704622948
#  physical_device_desc: "device: 0, name: A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0"
#  xla_global_id: 416903419]

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
import pickle
import cloudpickle
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from collections import Counter 

# to explore text in captions data
import nltk
nltk.download('stopwords')
import regex as re
from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS
from sklearn.feature_extraction.text import CountVectorizer

# to process the images
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# to process the text
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# for modelling
from tensorflow.keras.models import Model
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger

#utilities
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, add
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# ## Set Directories

# %%
# set directories
BASE_DIR = mount + "/My Drive/Colab Notebooks/Capstone/Data/flickr8k"
WORKING_DIR = mount + "/My Drive/Colab Notebooks/Capstone/Code"

# %% [markdown]
# ## Load Features From Pickle

# %%
# load features from pickle
with open(os.path.join(WORKING_DIR, 'features_inceptionv3.pkl'), 'rb') as f:
    features = pickle.load(f)

# %% [markdown]
# ## Load Captions Data

# %%
with open(os.path.join(BASE_DIR, 'captions.txt'), 'r') as f:
    next(f)
    captions_doc = f.read()

# %% [markdown]
# ## Map Image to Captions

# %%
# create mapping of image to captions
mapping = {}
#process lines
for line in tqdm(captions_doc.split('\n')):
    #split the line by comma(,)
    tokens = line.split(',')
    if len(line) < 2:
        continue
    image_id, caption = tokens[0], tokens[1:]
    #remove extension from image ID
    image_id = image_id.split('.')[0]
    #convert caption list to string
    caption = ' '.join(caption)
    #create list if needed
    if image_id not in mapping:
        mapping[image_id] = []
    mapping[image_id].append(caption)
# Out:
#   0%|          | 0/40456 [00:00<?, ?it/s]

# %%
len(mapping)
# Out:
# 8091

# %% [markdown]
# ## Preprocess the Captions Data

# %%
def clean(mapping):
    for key, captions in mapping.items():
        for i in range(len(captions)):
            #take one caption at a time
            caption = captions[i]
            #preprocessing steps
            #convert to lowercase
            caption = caption.lower()
            #replace all digits, special characters, etc.
            caption = caption.replace('[^A-Za-z]', '')
            #delete additional spaces
            caption = caption.replace('\s+', ' ')
            #add start and end tags to captions
            caption = 'startseq ' + ' '.join([word for word in caption.split() if len(word)>1]) + ' endseq'
            captions[i] = caption

# %%
# before preprocessing of text
mapping['1000268201_693b08cb0e']
# Out:
# ['A child in a pink dress is climbing up a set of stairs in an entry way .',
#  'A girl going into a wooden building .',
#  'A little girl climbing into a wooden playhouse .',
#  'A little girl climbing the stairs to her playhouse .',
#  'A little girl in a pink dress going into a wooden cabin .']

# %%
#preprocess the text
clean(mapping)

# %%
#after preprocessing of text
mapping['1000268201_693b08cb0e']
# Out:
# ['startseq child in pink dress is climbing up set of stairs in an entry way endseq',
#  'startseq girl going into wooden building endseq',
#  'startseq little girl climbing into wooden playhouse endseq',
#  'startseq little girl climbing the stairs to her playhouse endseq',
#  'startseq little girl in pink dress going into wooden cabin endseq']

# %%
all_captions = []
for key in mapping:
    for caption in mapping[key]:
        all_captions.append(caption)

# %%
len(all_captions)
# Out:
# 40455

# %%
all_captions[:10]
# Out:
# ['startseq child in pink dress is climbing up set of stairs in an entry way endseq',
#  'startseq girl going into wooden building endseq',
#  'startseq little girl climbing into wooden playhouse endseq',
#  'startseq little girl climbing the stairs to her playhouse endseq',
#  'startseq little girl in pink dress going into wooden cabin endseq',
#  'startseq black dog and spotted dog are fighting endseq',
#  'startseq black dog and tri-colored dog playing with each other on the road endseq',
#  'startseq black dog and white dog with brown spots are staring at each other in the street endseq',
#  'startseq two dogs of different breeds looking at each other on the road endseq',
#  'startseq two dogs on pavement moving toward each other endseq']

# %%
# tokenize the text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(all_captions)
vocab_size = len(tokenizer.word_index) + 1 #index up to the greatest token ID

# %%
#number of unique words
vocab_size
# Out:
# 8485

# %%
# get maximum length of caption available
max_length = max(len(caption.split()) for caption in all_captions)
max_length
# Out:
# 35

# %% [markdown]
# ## Train/Test Split

# %%
import random

image_ids = list(mapping.keys())
print(len(image_ids))
# Out:
# 8091

# %%
train = random.sample(image_ids, 6091)
test = random.sample(image_ids, 1000)
val = random.sample(image_ids, 1000)

# %%
print(len(train))
print(len(val))
print(len(test))
# Out:
# 6091
# 1000
# 1000

# %% [markdown]
# ## Create Data Generation Function

# %%
# create data generator to get data in batches (avoid session crashing)

# startseq girl going into wooden building endseq
#        X                   y
# startseq                   girl
# startseq girl              going
# startseq girl going        into
# ...........
# startseq girl going into wooden building      endseq

def data_generator(data_keys, mapping, features, tokenizer, max_length, vocab_size, batch_size):
    #loop over images
    X1, X2, y = list(), list(), list()
    n = 0
    while 1:
        for key in data_keys:
            n += 1
            captions = mapping[key]
            #process each caption
            for caption in captions:
                #encode the sequence
                seq = tokenizer.texts_to_sequences([caption])[0]
                # split the sequence into X, y pairs
                for i in range(1, len(seq)):
                    #split into input and output pairs
                    in_seq, out_seq = seq[:i], seq[i]
                    # pad input sequence for common length
                    in_seq = pad_sequences([in_seq], maxlen = max_length)[0]
                    # encode output sequence (like one hot encoding)
                    out_seq = to_categorical([out_seq], num_classes = vocab_size)[0]
                    
                    #store the sequences
                    X1.append(features[key][0])
                    X2.append(in_seq)
                    y.append(out_seq)
                    
            if n == batch_size:
                X1, X2, y = np.array(X1), np.array(X2), np.array(y)
                yield [X1, X2], y
                X1, X2, y = list(), list(), list()
                n = 0

# %% [markdown]
# ## Model Creation - CNN LSTM (Base plus Dropout Model)

# %%
# encoder model
# image feature layers
inputs1 = Input(shape = (2048,))
fe1 = Dropout(0.6)(inputs1) #increase dropout to 0.6 to avoid overfitting
fe2 = Dense(256, activation = 'relu')(fe1)

#sequence feature layers
inputs2 = Input(shape=(max_length,))
se1 = Embedding(vocab_size, 256, mask_zero = True)(inputs2)
se2 = Dropout(0.6)(se1) #increase dropout 0.6 to avoid overfitting
se3 = LSTM(256)(se2)

#decoder model
decoder1 = add([fe2, se3])
decoder2 = Dense(256, activation = 'relu')(decoder1)
outputs = Dense(vocab_size, activation = 'softmax')(decoder2)

final_model = Model(inputs=[inputs1, inputs2], outputs = outputs)

# plot the model
plot_model(final_model, show_shapes = True)

# %%
final_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 35)]         0           []
#
#  input_1 (InputLayer)           [(None, 2048)]       0           []
#
#  embedding (Embedding)          (None, 35, 256)      2172160     ['input_2[0][0]']
#
#  dropout (Dropout)              (None, 2048)         0           ['input_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 35, 256)      0           ['embedding[0][0]']
#
#  dense (Dense)                  (None, 256)          524544      ['dropout[0][0]']
#
#  lstm (LSTM)                    (None, 256)          525312      ['dropout_1[0][0]']
#
#  add (Add)                      (None, 256)          0           ['dense[0][0]',
#                                                                   'lstm[0][0]']
#
#  dense_1 (Dense)                (None, 256)          65792       ['add[0][0]']
#
#  dense_2 (Dense)                (None, 8485)         2180645     ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 5,468,453
# Trainable params: 5,468,453
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
#Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
final_model.compile(loss = 'categorical_crossentropy', optimizer = opt, metrics=['accuracy'])

# %%
# Train the model
epochs = 300
batch_size = 32
steps = len(train) // batch_size
val_steps = len(test) // batch_size

#Interrupts training when improvement stops and monitor the model's val acc
#Interrupts training when accuracy nas stopped improving for more than 5 epochs.
callbacks_list = tf.keras.callbacks.EarlyStopping(monitor = 'accuracy', patience = 5,)

#save results of model fit in a CSV file
csv_log = CSVLogger("base_inceptionv3_dropout_results.csv")

# create data generator
generator = data_generator(train, mapping, features, tokenizer, max_length, vocab_size, batch_size)
val_generator = data_generator(val, mapping, features, tokenizer, max_length, vocab_size, batch_size)
#fit for one epoch
history = final_model.fit(generator, epochs = epochs, steps_per_epoch = steps, validation_data=val_generator, callbacks=(callbacks_list, csv_log), validation_steps=val_steps, verbose  = 1)
# Out:
# Epoch 1/300
# 190/190 [==============================] - 35s 147ms/step - loss: 5.4537 - accuracy: 0.1423 - val_loss: 4.5538 - val_accuracy: 0.2093
# Epoch 2/300
# 190/190 [==============================] - 26s 140ms/step - loss: 4.2462 - accuracy: 0.2385 - val_loss: 3.9695 - val_accuracy: 0.2644
# Epoch 3/300
# 190/190 [==============================] - 27s 141ms/step - loss: 3.8306 - accuracy: 0.2707 - val_loss: 3.7073 - val_accuracy: 0.2867
# Epoch 4/300
# 190/190 [==============================] - 27s 140ms/step - loss: 3.5903 - accuracy: 0.2884 - val_loss: 3.5410 - val_accuracy: 0.3017
# Epoch 5/300
# 190/190 [==============================] - 27s 140ms/step - loss: 3.4158 - accuracy: 0.3009 - val_loss: 3.4558 - val_accuracy: 0.3119
# Epoch 6/300
# 190/190 [==============================] - 27s 142ms/step - loss: 3.2724 - accuracy: 0.3125 - val_loss: 3.4226 - val_accuracy: 0.3185
# Epoch 7/300
# 190/190 [==============================] - 27s 141ms/step - loss: 3.1564 - accuracy: 0.3219 - val_loss: 3.3792 - val_accuracy: 0.3255
# Epoch 8/300
# 190/190 [==============================] - 27s 142ms/step - loss: 3.0531 - accuracy: 0.3300 - val_loss: 3.3175 - val_accuracy: 0.3315
# Epoch 9/300
# 190/190 [==============================] - 27s 143ms/step - loss: 2.9655 - accuracy: 0.3389 - val_loss: 3.2632 - val_accuracy: 0.3352
# Epoch 10/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.8831 - accuracy: 0.3480 - val_loss: 3.2338 - val_accuracy: 0.3381
# Epoch 11/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.8149 - accuracy: 0.3566 - val_loss: 3.2475 - val_accuracy: 0.3410
# Epoch 12/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.7544 - accuracy: 0.3630 - val_loss: 3.1862 - val_accuracy: 0.3475
# Epoch 13/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.6980 - accuracy: 0.3703 - val_loss: 3.1575 - val_accuracy: 0.3499
# Epoch 14/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.6563 - accuracy: 0.3750 - val_loss: 3.1574 - val_accuracy: 0.3527
# Epoch 15/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.6086 - accuracy: 0.3804 - val_loss: 3.1305 - val_accuracy: 0.3576
# Epoch 16/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.5698 - accuracy: 0.3866 - val_loss: 3.0660 - val_accuracy: 0.3638
# Epoch 17/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.5230 - accuracy: 0.3925 - val_loss: 3.0240 - val_accuracy: 0.3709
# Epoch 18/300
# 190/190 [==============================] - 27s 142ms/step - loss: 2.4857 - accuracy: 0.3976 - val_loss: 3.0043 - val_accuracy: 0.3724
# Epoch 19/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.4501 - accuracy: 0.4029 - val_loss: 3.0184 - val_accuracy: 0.3728
# Epoch 20/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.4186 - accuracy: 0.4080 - val_loss: 2.9844 - val_accuracy: 0.3759
# Epoch 21/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.3911 - accuracy: 0.4121 - val_loss: 2.9263 - val_accuracy: 0.3800
# Epoch 22/300
# 190/190 [==============================] - 26s 139ms/step - loss: 2.3661 - accuracy: 0.4147 - val_loss: 2.9516 - val_accuracy: 0.3800
# Epoch 23/300
# 190/190 [==============================] - 26s 139ms/step - loss: 2.3354 - accuracy: 0.4203 - val_loss: 2.9503 - val_accuracy: 0.3828
# Epoch 24/300
# 190/190 [==============================] - 26s 139ms/step - loss: 2.3169 - accuracy: 0.4218 - val_loss: 2.9171 - val_accuracy: 0.3842
# Epoch 25/300
# 190/190 [==============================] - 26s 139ms/step - loss: 2.2906 - accuracy: 0.4268 - val_loss: 2.9047 - val_accuracy: 0.3878
# Epoch 26/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.2692 - accuracy: 0.4301 - val_loss: 2.8964 - val_accuracy: 0.3897
# Epoch 27/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.2482 - accuracy: 0.4329 - val_loss: 2.8882 - val_accuracy: 0.3904
# Epoch 28/300
# 190/190 [==============================] - 26s 139ms/step - loss: 2.2273 - accuracy: 0.4366 - val_loss: 2.8894 - val_accuracy: 0.3918
# Epoch 29/300
# 190/190 [==============================] - 26s 139ms/step - loss: 2.2097 - accuracy: 0.4395 - val_loss: 2.9099 - val_accuracy: 0.3939
# Epoch 30/300
# 190/190 [==============================] - 26s 139ms/step - loss: 2.1913 - accuracy: 0.4428 - val_loss: 2.9216 - val_accuracy: 0.3944
# Epoch 31/300
# 190/190 [==============================] - 26s 139ms/step - loss: 2.1743 - accuracy: 0.4455 - val_loss: 2.9044 - val_accuracy: 0.3966
# Epoch 32/300
# 190/190 [==============================] - 26s 139ms/step - loss: 2.1564 - accuracy: 0.4484 - val_loss: 2.8560 - val_accuracy: 0.4017
# Epoch 33/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.1397 - accuracy: 0.4512 - val_loss: 2.8492 - val_accuracy: 0.4057
# Epoch 34/300
# 190/190 [==============================] - 26s 139ms/step - loss: 2.1235 - accuracy: 0.4536 - val_loss: 2.8680 - val_accuracy: 0.4060
# Epoch 35/300
# 190/190 [==============================] - 26s 139ms/step - loss: 2.1092 - accuracy: 0.4559 - val_loss: 2.8796 - val_accuracy: 0.4056
# Epoch 36/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.0967 - accuracy: 0.4578 - val_loss: 2.9019 - val_accuracy: 0.4042
# Epoch 37/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.0863 - accuracy: 0.4597 - val_loss: 2.9032 - val_accuracy: 0.4069
# Epoch 38/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.0712 - accuracy: 0.4627 - val_loss: 2.8892 - val_accuracy: 0.4088
# Epoch 39/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.0607 - accuracy: 0.4647 - val_loss: 2.8571 - val_accuracy: 0.4128
# Epoch 40/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.0520 - accuracy: 0.4660 - val_loss: 2.8441 - val_accuracy: 0.4152
# Epoch 41/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.0417 - accuracy: 0.4666 - val_loss: 2.8382 - val_accuracy: 0.4166
# Epoch 42/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.0297 - accuracy: 0.4693 - val_loss: 2.8763 - val_accuracy: 0.4149
# Epoch 43/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.0228 - accuracy: 0.4707 - val_loss: 2.8998 - val_accuracy: 0.4160
# Epoch 44/300
# 190/190 [==============================] - 26s 139ms/step - loss: 2.0145 - accuracy: 0.4723 - val_loss: 2.8941 - val_accuracy: 0.4169
# Epoch 45/300
# 190/190 [==============================] - 26s 139ms/step - loss: 2.0014 - accuracy: 0.4749 - val_loss: 2.8942 - val_accuracy: 0.4187
# Epoch 46/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.9966 - accuracy: 0.4747 - val_loss: 2.9059 - val_accuracy: 0.4175
# Epoch 47/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.9891 - accuracy: 0.4770 - val_loss: 2.9022 - val_accuracy: 0.4201
# Epoch 48/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.9774 - accuracy: 0.4789 - val_loss: 2.8868 - val_accuracy: 0.4234
# Epoch 49/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.9693 - accuracy: 0.4805 - val_loss: 2.9019 - val_accuracy: 0.4200
# Epoch 50/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.9618 - accuracy: 0.4812 - val_loss: 2.8932 - val_accuracy: 0.4231
# Epoch 51/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.9567 - accuracy: 0.4828 - val_loss: 2.8988 - val_accuracy: 0.4249
# Epoch 52/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.9449 - accuracy: 0.4850 - val_loss: 2.8734 - val_accuracy: 0.4284
# Epoch 53/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.9369 - accuracy: 0.4862 - val_loss: 2.8668 - val_accuracy: 0.4285
# Epoch 54/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.9314 - accuracy: 0.4871 - val_loss: 2.8586 - val_accuracy: 0.4295
# Epoch 55/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.9184 - accuracy: 0.4891 - val_loss: 2.8588 - val_accuracy: 0.4305
# Epoch 56/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.9144 - accuracy: 0.4911 - val_loss: 2.8467 - val_accuracy: 0.4305
# Epoch 57/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.9068 - accuracy: 0.4900 - val_loss: 2.8425 - val_accuracy: 0.4329
# Epoch 58/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.8986 - accuracy: 0.4938 - val_loss: 2.8279 - val_accuracy: 0.4338
# Epoch 59/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.8917 - accuracy: 0.4943 - val_loss: 2.8143 - val_accuracy: 0.4343
# Epoch 60/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.8847 - accuracy: 0.4951 - val_loss: 2.8164 - val_accuracy: 0.4369
# Epoch 61/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.8753 - accuracy: 0.4976 - val_loss: 2.8340 - val_accuracy: 0.4359
# Epoch 62/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.8709 - accuracy: 0.4984 - val_loss: 2.8427 - val_accuracy: 0.4343
# Epoch 63/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.8583 - accuracy: 0.5015 - val_loss: 2.8325 - val_accuracy: 0.4365
# Epoch 64/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.8545 - accuracy: 0.5006 - val_loss: 2.8408 - val_accuracy: 0.4382
# Epoch 65/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.8488 - accuracy: 0.5030 - val_loss: 2.8512 - val_accuracy: 0.4375
# Epoch 66/300
# 190/190 [==============================] - 26s 140ms/step - loss: 1.8408 - accuracy: 0.5041 - val_loss: 2.8703 - val_accuracy: 0.4382
# Epoch 67/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.8377 - accuracy: 0.5036 - val_loss: 2.8731 - val_accuracy: 0.4368
# Epoch 68/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.8326 - accuracy: 0.5051 - val_loss: 2.8840 - val_accuracy: 0.4351
# Epoch 69/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.8262 - accuracy: 0.5065 - val_loss: 2.8586 - val_accuracy: 0.4390
# Epoch 70/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.8204 - accuracy: 0.5081 - val_loss: 2.8555 - val_accuracy: 0.4401
# Epoch 71/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.8159 - accuracy: 0.5074 - val_loss: 2.8351 - val_accuracy: 0.4449
# Epoch 72/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.8065 - accuracy: 0.5107 - val_loss: 2.8498 - val_accuracy: 0.4443
# Epoch 73/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.8028 - accuracy: 0.5105 - val_loss: 2.8655 - val_accuracy: 0.4432
# Epoch 74/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.7968 - accuracy: 0.5124 - val_loss: 2.8590 - val_accuracy: 0.4455
# Epoch 75/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.7909 - accuracy: 0.5131 - val_loss: 2.8825 - val_accuracy: 0.4408
# Epoch 76/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.7848 - accuracy: 0.5145 - val_loss: 2.8921 - val_accuracy: 0.4435
# Epoch 77/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.7836 - accuracy: 0.5153 - val_loss: 2.8639 - val_accuracy: 0.4488
# Epoch 78/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.7794 - accuracy: 0.5154 - val_loss: 2.8892 - val_accuracy: 0.4432
# Epoch 79/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.7723 - accuracy: 0.5168 - val_loss: 2.8904 - val_accuracy: 0.4458
# Epoch 80/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.7656 - accuracy: 0.5180 - val_loss: 2.9020 - val_accuracy: 0.4475
# Epoch 81/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.7609 - accuracy: 0.5200 - val_loss: 2.9014 - val_accuracy: 0.4464
# Epoch 82/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.7525 - accuracy: 0.5209 - val_loss: 2.9012 - val_accuracy: 0.4467
# Epoch 83/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.7488 - accuracy: 0.5212 - val_loss: 2.8510 - val_accuracy: 0.4501
# Epoch 84/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.7441 - accuracy: 0.5217 - val_loss: 2.8709 - val_accuracy: 0.4527
# Epoch 85/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.7418 - accuracy: 0.5218 - val_loss: 2.8642 - val_accuracy: 0.4518
# Epoch 86/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.7373 - accuracy: 0.5229 - val_loss: 2.9266 - val_accuracy: 0.4493
# Epoch 87/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.7351 - accuracy: 0.5241 - val_loss: 2.8934 - val_accuracy: 0.4524
# Epoch 88/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.7312 - accuracy: 0.5249 - val_loss: 2.8845 - val_accuracy: 0.4527
# Epoch 89/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.7269 - accuracy: 0.5258 - val_loss: 2.9267 - val_accuracy: 0.4501
# Epoch 90/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.7198 - accuracy: 0.5275 - val_loss: 2.9767 - val_accuracy: 0.4507
# Epoch 91/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.7170 - accuracy: 0.5276 - val_loss: 2.9753 - val_accuracy: 0.4512
# Epoch 92/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.7120 - accuracy: 0.5287 - val_loss: 2.9589 - val_accuracy: 0.4504
# Epoch 93/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.7070 - accuracy: 0.5296 - val_loss: 2.9673 - val_accuracy: 0.4511
# Epoch 94/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.7030 - accuracy: 0.5303 - val_loss: 3.0002 - val_accuracy: 0.4504
# Epoch 95/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.6979 - accuracy: 0.5319 - val_loss: 2.9759 - val_accuracy: 0.4531
# Epoch 96/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.6980 - accuracy: 0.5328 - val_loss: 2.9585 - val_accuracy: 0.4542
# Epoch 97/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.6944 - accuracy: 0.5328 - val_loss: 2.9781 - val_accuracy: 0.4522
# Epoch 98/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.6909 - accuracy: 0.5327 - val_loss: 2.9857 - val_accuracy: 0.4515
# Epoch 99/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.6907 - accuracy: 0.5326 - val_loss: 2.9755 - val_accuracy: 0.4540
# Epoch 100/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.6914 - accuracy: 0.5332 - val_loss: 2.9672 - val_accuracy: 0.4566
# Epoch 101/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.6881 - accuracy: 0.5324 - val_loss: 2.9807 - val_accuracy: 0.4562
# Epoch 102/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.6846 - accuracy: 0.5346 - val_loss: 2.9670 - val_accuracy: 0.4562
# Epoch 103/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.6786 - accuracy: 0.5352 - val_loss: 2.9771 - val_accuracy: 0.4557
# Epoch 104/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.6767 - accuracy: 0.5354 - val_loss: 3.0178 - val_accuracy: 0.4544
# Epoch 105/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.6693 - accuracy: 0.5364 - val_loss: 2.9833 - val_accuracy: 0.4571
# Epoch 106/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.6657 - accuracy: 0.5375 - val_loss: 2.9914 - val_accuracy: 0.4572
# Epoch 107/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.6645 - accuracy: 0.5390 - val_loss: 3.0110 - val_accuracy: 0.4561
# Epoch 108/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.6609 - accuracy: 0.5393 - val_loss: 2.9964 - val_accuracy: 0.4596
# Epoch 109/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.6568 - accuracy: 0.5401 - val_loss: 2.9815 - val_accuracy: 0.4595
# Epoch 110/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.6572 - accuracy: 0.5390 - val_loss: 2.9880 - val_accuracy: 0.4594
# Epoch 111/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.6503 - accuracy: 0.5404 - val_loss: 2.9964 - val_accuracy: 0.4598
# Epoch 112/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.6504 - accuracy: 0.5413 - val_loss: 2.9855 - val_accuracy: 0.4622
# Epoch 113/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.6490 - accuracy: 0.5411 - val_loss: 2.9637 - val_accuracy: 0.4635
# Epoch 114/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.6411 - accuracy: 0.5431 - val_loss: 2.9411 - val_accuracy: 0.4659
# Epoch 115/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.6363 - accuracy: 0.5441 - val_loss: 2.9607 - val_accuracy: 0.4623
# Epoch 116/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.6332 - accuracy: 0.5439 - val_loss: 2.9902 - val_accuracy: 0.4634
# Epoch 117/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.6312 - accuracy: 0.5442 - val_loss: 2.9799 - val_accuracy: 0.4635
# Epoch 118/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.6266 - accuracy: 0.5458 - val_loss: 3.0444 - val_accuracy: 0.4634
# Epoch 119/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.6218 - accuracy: 0.5469 - val_loss: 3.0467 - val_accuracy: 0.4612
# Epoch 120/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.6198 - accuracy: 0.5473 - val_loss: 3.0643 - val_accuracy: 0.4589
# Epoch 121/300
# 190/190 [==============================] - 26s 137ms/step - loss: 1.6132 - accuracy: 0.5496 - val_loss: 3.0952 - val_accuracy: 0.4605
# Epoch 122/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.6104 - accuracy: 0.5482 - val_loss: 3.1471 - val_accuracy: 0.4556
# Epoch 123/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.6053 - accuracy: 0.5502 - val_loss: 3.1571 - val_accuracy: 0.4570
# Epoch 124/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.6069 - accuracy: 0.5504 - val_loss: 3.2354 - val_accuracy: 0.4534
# Epoch 125/300
# 190/190 [==============================] - 26s 137ms/step - loss: 1.6018 - accuracy: 0.5517 - val_loss: 3.2691 - val_accuracy: 0.4541
# Epoch 126/300
# 190/190 [==============================] - 26s 137ms/step - loss: 1.6020 - accuracy: 0.5513 - val_loss: 3.2949 - val_accuracy: 0.4538
# Epoch 127/300
# 190/190 [==============================] - 26s 136ms/step - loss: 1.5981 - accuracy: 0.5516 - val_loss: 3.2351 - val_accuracy: 0.4569
# Epoch 128/300
# 190/190 [==============================] - 26s 137ms/step - loss: 1.5935 - accuracy: 0.5531 - val_loss: 3.2851 - val_accuracy: 0.4559
# Epoch 129/300
# 190/190 [==============================] - 26s 137ms/step - loss: 1.5928 - accuracy: 0.5523 - val_loss: 3.3008 - val_accuracy: 0.4511
# Epoch 130/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5900 - accuracy: 0.5525 - val_loss: 3.3341 - val_accuracy: 0.4508
# Epoch 131/300
# 190/190 [==============================] - 26s 136ms/step - loss: 1.5887 - accuracy: 0.5534 - val_loss: 3.3090 - val_accuracy: 0.4512
# Epoch 132/300
# 190/190 [==============================] - 26s 136ms/step - loss: 1.5861 - accuracy: 0.5541 - val_loss: 3.3458 - val_accuracy: 0.4525
# Epoch 133/300
# 190/190 [==============================] - 26s 137ms/step - loss: 1.5867 - accuracy: 0.5541 - val_loss: 3.2884 - val_accuracy: 0.4572
# Epoch 134/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5861 - accuracy: 0.5543 - val_loss: 3.2787 - val_accuracy: 0.4539
# Epoch 135/300
# 190/190 [==============================] - 26s 137ms/step - loss: 1.5831 - accuracy: 0.5540 - val_loss: 3.3037 - val_accuracy: 0.4534
# Epoch 136/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5798 - accuracy: 0.5551 - val_loss: 3.3653 - val_accuracy: 0.4515
# Epoch 137/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5804 - accuracy: 0.5550 - val_loss: 3.4218 - val_accuracy: 0.4482
# Epoch 138/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5782 - accuracy: 0.5558 - val_loss: 3.4156 - val_accuracy: 0.4495
# Epoch 139/300
# 190/190 [==============================] - 26s 137ms/step - loss: 1.5767 - accuracy: 0.5560 - val_loss: 3.3479 - val_accuracy: 0.4528
# Epoch 140/300
# 190/190 [==============================] - 26s 136ms/step - loss: 1.5723 - accuracy: 0.5572 - val_loss: 3.3111 - val_accuracy: 0.4573
# Epoch 141/300
# 190/190 [==============================] - 26s 136ms/step - loss: 1.5668 - accuracy: 0.5577 - val_loss: 3.2992 - val_accuracy: 0.4583
# Epoch 142/300
# 190/190 [==============================] - 26s 137ms/step - loss: 1.5683 - accuracy: 0.5574 - val_loss: 3.2610 - val_accuracy: 0.4581
# Epoch 143/300
# 190/190 [==============================] - 26s 136ms/step - loss: 1.5660 - accuracy: 0.5571 - val_loss: 3.2766 - val_accuracy: 0.4541
# Epoch 144/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5611 - accuracy: 0.5585 - val_loss: 3.2645 - val_accuracy: 0.4579
# Epoch 145/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5597 - accuracy: 0.5596 - val_loss: 3.2798 - val_accuracy: 0.4562
# Epoch 146/300
# 190/190 [==============================] - 26s 137ms/step - loss: 1.5608 - accuracy: 0.5584 - val_loss: 3.2724 - val_accuracy: 0.4584
# Epoch 147/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5551 - accuracy: 0.5600 - val_loss: 3.2317 - val_accuracy: 0.4590
# Epoch 148/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.5549 - accuracy: 0.5600 - val_loss: 3.1062 - val_accuracy: 0.4663
# Epoch 149/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5530 - accuracy: 0.5607 - val_loss: 3.1273 - val_accuracy: 0.4672
# Epoch 150/300
# 190/190 [==============================] - 26s 137ms/step - loss: 1.5514 - accuracy: 0.5613 - val_loss: 3.1654 - val_accuracy: 0.4670
# Epoch 151/300
# 190/190 [==============================] - 26s 137ms/step - loss: 1.5504 - accuracy: 0.5621 - val_loss: 3.2123 - val_accuracy: 0.4626
# Epoch 152/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5457 - accuracy: 0.5618 - val_loss: 3.1936 - val_accuracy: 0.4632
# Epoch 153/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.5428 - accuracy: 0.5633 - val_loss: 3.2469 - val_accuracy: 0.4622
# Epoch 154/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.5400 - accuracy: 0.5642 - val_loss: 3.1965 - val_accuracy: 0.4669
# Epoch 155/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5394 - accuracy: 0.5642 - val_loss: 3.1506 - val_accuracy: 0.4691
# Epoch 156/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5349 - accuracy: 0.5645 - val_loss: 3.1266 - val_accuracy: 0.4718
# Epoch 157/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5320 - accuracy: 0.5656 - val_loss: 3.1301 - val_accuracy: 0.4712
# Epoch 158/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5297 - accuracy: 0.5665 - val_loss: 3.1116 - val_accuracy: 0.4732
# Epoch 159/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5285 - accuracy: 0.5652 - val_loss: 3.1201 - val_accuracy: 0.4717
# Epoch 160/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.5247 - accuracy: 0.5668 - val_loss: 3.1214 - val_accuracy: 0.4740
# Epoch 161/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.5225 - accuracy: 0.5676 - val_loss: 3.0702 - val_accuracy: 0.4758
# Epoch 162/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5230 - accuracy: 0.5675 - val_loss: 3.0720 - val_accuracy: 0.4787
# Epoch 163/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5204 - accuracy: 0.5680 - val_loss: 3.0444 - val_accuracy: 0.4796
# Epoch 164/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5210 - accuracy: 0.5685 - val_loss: 2.9978 - val_accuracy: 0.4841
# Epoch 165/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5171 - accuracy: 0.5685 - val_loss: 2.9944 - val_accuracy: 0.4859
# Epoch 166/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5198 - accuracy: 0.5683 - val_loss: 3.0234 - val_accuracy: 0.4820
# Epoch 167/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5114 - accuracy: 0.5695 - val_loss: 3.0173 - val_accuracy: 0.4841
# Epoch 168/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.5112 - accuracy: 0.5703 - val_loss: 2.9753 - val_accuracy: 0.4883
# Epoch 169/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.5097 - accuracy: 0.5697 - val_loss: 2.9465 - val_accuracy: 0.4890
# Epoch 170/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.5089 - accuracy: 0.5699 - val_loss: 2.9613 - val_accuracy: 0.4887
# Epoch 171/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.5093 - accuracy: 0.5692 - val_loss: 2.9456 - val_accuracy: 0.4894
# Epoch 172/300
# 190/190 [==============================] - 26s 138ms/step - loss: 1.5106 - accuracy: 0.5697 - val_loss: 2.9425 - val_accuracy: 0.4932
# Epoch 173/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.5108 - accuracy: 0.5695 - val_loss: 2.9622 - val_accuracy: 0.4910

# %%
# save the model
final_model.save(WORKING_DIR + '/base_val_inceptionv3_dropout_model.h5')

# %% [markdown]
# ### Visualizing Model Accuracy and Loss

# %%
#load CSV file
data = pd.read_csv(mount + "/My Drive/Colab Notebooks/Capstone/Code/base_inceptionv3_dropout_results.csv")
data.head()
# Out:
#    epoch  accuracy      loss  val_accuracy  val_loss
# 0      0  0.142259  5.453727      0.209334  4.553757
# 1      1  0.238453  4.246202      0.264383  3.969539
# 2      2  0.270677  3.830556      0.286723  3.707335
# 3      3  0.288363  3.590271      0.301706  3.540980
# 4      4  0.300869  3.415826      0.311862  3.455818

# %%
# Plot Training/Val Accuracy by Epoch for Base Inception v3 plus Dropout Model
plt.title('Train/Val Accuracy by Epoch (Base Inception v3 plus Dropout Model)', fontsize = 25)
plt.plot(data['accuracy'], color='blue', label='accuracy')
plt.plot(data['val_accuracy'], color='red', label='val_accuracy')
plt.xlabel('Epoch', fontsize = 18)
plt.ylabel('Categorical Crossentropy', fontsize = 18)
plt.rcParams["figure.figsize"] = (12,8)
plt.legend()
plt.show()

# %%
# Plot Training/Val Loss by Epoch for Base Inception v3 plus Dropout Model
plt.title('Train/Val Loss by Epoch (Base Inception v3 plus Dropout Model)', fontsize = 25)
plt.plot(data['loss'], color='orange', label='loss')
plt.plot(data['val_loss'], color='green', label='val_loss')
plt.xlabel('Epoch', fontsize = 18)
plt.ylabel('Categorical Crossentropy', fontsize = 18)
plt.rcParams["figure.figsize"] = (12,8)
plt.legend()
plt.show()

# %% [markdown]
# ## Generate Captions for Images

# %%
def idx_to_word(integer, tokenizer):
    for word, index in tokenizer.word_index.items():
        if index == integer:
            return word
    return None

# %%
# generate caption for an image
def predict_caption(model, image, tokenizer, max_length):
    #add start tag for generation process
    in_text = 'startseq'
    #iterate over the max length of sequence
    for i in range(max_length):
        #encode input sequence
        sequence = tokenizer.texts_to_sequences([in_text])[0]
        #pad the sequence
        sequence = pad_sequences([sequence], max_length)
        #predict next word
        yhat = final_model.predict([image, sequence], verbose = 0)
        #get index with high probability
        yhat= np.argmax(yhat)
        #convert index to word
        word = idx_to_word(yhat, tokenizer)
        #stop if word not found
        if word is None:
            break
        #append word as input for generation next word
        in_text += ' ' + word
        #stop if we reach end tag
        if word == 'endseq':
            break
    return in_text

# %% [markdown]
# ### BLEU Score

# %%
from nltk.translate.bleu_score import corpus_bleu

# %%
# validate with test data
actual, predicted = list(), list()

for key in tqdm(test):
    #get actual caption
    captions = mapping[key]
    #predict the caption for image
    y_pred = predict_caption(final_model, features[key], tokenizer, max_length)
    #split into words  
    actual_captions = [caption.split() for caption in captions]
    y_pred = y_pred.split()
    #append to the list
    actual.append(actual_captions)
    predicted.append(y_pred)
    
#calculate BLEU Score
print("BLEU-1: %f" % corpus_bleu(actual, predicted, weights = (1.0, 0, 0, 0)))
print("BLEU-2: %f" % corpus_bleu(actual, predicted, weights = (0.5, 0.5, 0, 0)))
print("BLEU-3: %f" % corpus_bleu(actual, predicted, weights = (0.3, 0.3, 0.3, 0.1)))
print("BLEU-4: %f" % corpus_bleu(actual, predicted, weights = (0.25, 0.25, 0.25, 0.25)))
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# ## Visualize the Results of Image Captions

# %%
from PIL import Image
import matplotlib.pyplot as plt

def generate_caption(image_name):
    #load the image
    image_id = image_name.split('.')[0]
    img_path = os.path.join(BASE_DIR, "Images", image_name)
    image = Image.open(img_path)
    captions = mapping[image_id]
    print('-----------Actual-----------')
    for caption in captions:
        print(caption)

    #predict the caption
    y_pred = predict_caption(final_model, features[image_id], tokenizer, max_length)
    print('-----------Predicted-----------')
    print(y_pred)
    plt.imshow(image)

# %%
generate_caption("421808539_57abee6d55.jpg")

# %%
generate_caption("1193116658_c0161c35b5.jpg")

# %%
generate_caption("1285067106_2adc307240.jpg")

# %%
generate_caption("516725192_c9cdd63878.jpg")
