# %% [markdown]
# # Part 3b - Image Caption Preprocessing and Modelling (VGG16 Base plus Dropout Model)

# %% [markdown]
# ## Mount Google Drive unto Colab Environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/Capstone/Code

# %%
# Check if in Colab Env
try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False

if IN_COLAB:
  print("We're running Colab")
# Out:
# We're running Colab

# %%
# Change Mount Location
if IN_COLAB:
  # Mount the Google Drive at mount
  mount='/content/drive/'
  print("Colab: mounting Google drive on ", mount)

  drive.mount(mount)

  # Switch to the directory on the Google Drive that you want to use
  import os
  drive_root = mount + "/My Drive/Colab Notebooks/Capstone/Code"
  
  # Create drive_root if it doesn't exist
  create_drive_root = True
  if create_drive_root:
    print("\nColab: making sure ", drive_root, " exists.")
    os.makedirs(drive_root, exist_ok=True)
  
  # Change to the directory
  print("\nColab: Changing directory to ", drive_root)
  # %cd $drive_root
# Out:
# Colab: mounting Google drive on  /content/drive/
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
#
# Colab: making sure  /content/drive//My Drive/Colab Notebooks/Capstone/Code  exists.
#
# Colab: Changing directory to  /content/drive//My Drive/Colab Notebooks/Capstone/Code
# /content/drive/My Drive/Colab Notebooks/Capstone/Code

# %%
# GPU
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 17550025300293955899
#  xla_global_id: -1]

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
import pickle
import cloudpickle
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
from collections import Counter 

# to explore text in captions data
import nltk
nltk.download('stopwords')
import regex as re
from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS
from sklearn.feature_extraction.text import CountVectorizer

# to process the images
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# to process the text
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# for modelling
from tensorflow.keras.models import Model
from keras.callbacks import ModelCheckpoint, EarlyStopping, CSVLogger

#utilities
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, add
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Set Directories

# %%
# set directories
BASE_DIR = mount + "/My Drive/Colab Notebooks/Capstone/Data/flickr8k"
WORKING_DIR = mount + "/My Drive/Colab Notebooks/Capstone/Code"

# %% [markdown]
# ## Load Features From Pickle

# %%
# load features from pickle
with open(os.path.join(WORKING_DIR, 'features.pkl'), 'rb') as f:
    features = pickle.load(f)

# %% [markdown]
# ## Load Captions Data

# %%
with open(os.path.join(BASE_DIR, 'captions.txt'), 'r') as f:
    next(f)
    captions_doc = f.read()

# %% [markdown]
# ## Map Image to Captions

# %%
# create mapping of image to captions
mapping = {}
#process lines
for line in tqdm(captions_doc.split('\n')):
    #split the line by comma(,)
    tokens = line.split(',')
    if len(line) < 2:
        continue
    image_id, caption = tokens[0], tokens[1:]
    #remove extension from image ID
    image_id = image_id.split('.')[0]
    #convert caption list to string
    caption = ' '.join(caption)
    #create list if needed
    if image_id not in mapping:
        mapping[image_id] = []
    mapping[image_id].append(caption)
# Out:
#   0%|          | 0/40456 [00:00<?, ?it/s]

# %%
len(mapping)
# Out:
# 8091

# %% [markdown]
# ## Preprocess the Captions Data

# %%
def clean(mapping):
    for key, captions in mapping.items():
        for i in range(len(captions)):
            #take one caption at a time
            caption = captions[i]
            #preprocessing steps
            #convert to lowercase
            caption = caption.lower()
            #replace all digits, special characters, etc.
            caption = caption.replace('[^A-Za-z]', '')
            #delete additional spaces
            caption = caption.replace('\s+', ' ')
            #add start and end tags to captions
            caption = 'startseq ' + ' '.join([word for word in caption.split() if len(word)>1]) + ' endseq'
            captions[i] = caption

# %%
# before preprocessing of text
mapping['1000268201_693b08cb0e']
# Out:
# ['A child in a pink dress is climbing up a set of stairs in an entry way .',
#  'A girl going into a wooden building .',
#  'A little girl climbing into a wooden playhouse .',
#  'A little girl climbing the stairs to her playhouse .',
#  'A little girl in a pink dress going into a wooden cabin .']

# %%
#preprocess the text
clean(mapping)

# %%
#after preprocessing of text
mapping['1000268201_693b08cb0e']
# Out:
# ['startseq child in pink dress is climbing up set of stairs in an entry way endseq',
#  'startseq girl going into wooden building endseq',
#  'startseq little girl climbing into wooden playhouse endseq',
#  'startseq little girl climbing the stairs to her playhouse endseq',
#  'startseq little girl in pink dress going into wooden cabin endseq']

# %%
all_captions = []
for key in mapping:
    for caption in mapping[key]:
        all_captions.append(caption)

# %%
len(all_captions)
# Out:
# 40455

# %%
all_captions[:10]
# Out:
# ['startseq child in pink dress is climbing up set of stairs in an entry way endseq',
#  'startseq girl going into wooden building endseq',
#  'startseq little girl climbing into wooden playhouse endseq',
#  'startseq little girl climbing the stairs to her playhouse endseq',
#  'startseq little girl in pink dress going into wooden cabin endseq',
#  'startseq black dog and spotted dog are fighting endseq',
#  'startseq black dog and tri-colored dog playing with each other on the road endseq',
#  'startseq black dog and white dog with brown spots are staring at each other in the street endseq',
#  'startseq two dogs of different breeds looking at each other on the road endseq',
#  'startseq two dogs on pavement moving toward each other endseq']

# %%
# tokenize the text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(all_captions)
vocab_size = len(tokenizer.word_index) + 1 #index up to the greatest token ID

# %%
#number of unique words
vocab_size
# Out:
# 8485

# %%
# get maximum length of caption available
max_length = max(len(caption.split()) for caption in all_captions)
max_length
# Out:
# 35

# %% [markdown]
# ## Train/Test Split

# %%
import random

image_ids = list(mapping.keys())
print(len(image_ids))
# Out:
# 8091

# %%
train = random.sample(image_ids, 6091)
test = random.sample(image_ids, 1000)
val = random.sample(image_ids, 1000)

# %%
print(len(train))
print(len(val))
print(len(test))
# Out:
# 6091
# 1000
# 1000

# %% [markdown]
# ## Create Data Generation Function

# %%
# create data generator to get data in batches (avoid session crashing)

# startseq girl going into wooden building endseq
#        X                   y
# startseq                   girl
# startseq girl              going
# startseq girl going        into
# ...........
# startseq girl going into wooden building      endseq

def data_generator(data_keys, mapping, features, tokenizer, max_length, vocab_size, batch_size):
    #loop over images
    X1, X2, y = list(), list(), list()
    n = 0
    while 1:
        for key in data_keys:
            n += 1
            captions = mapping[key]
            #process each caption
            for caption in captions:
                #encode the sequence
                seq = tokenizer.texts_to_sequences([caption])[0]
                # split the sequence into X, y pairs
                for i in range(1, len(seq)):
                    #split into input and output pairs
                    in_seq, out_seq = seq[:i], seq[i]
                    # pad input sequence for common length
                    in_seq = pad_sequences([in_seq], maxlen = max_length)[0]
                    # encode output sequence (like one hot encoding)
                    out_seq = to_categorical([out_seq], num_classes = vocab_size)[0]
                    
                    #store the sequences
                    X1.append(features[key][0])
                    X2.append(in_seq)
                    y.append(out_seq)
                    
            if n == batch_size:
                X1, X2, y = np.array(X1), np.array(X2), np.array(y)
                yield [X1, X2], y
                X1, X2, y = list(), list(), list()
                n = 0

# %% [markdown]
# ## Model Creation - CNN LSTM (Base plus Dropout Model)

# %%
# encoder model
# image feature layers
inputs1 = Input(shape = (4096,))
fe1 = Dropout(0.6)(inputs1) #increase dropout to 0.6 to avoid overfitting
fe2 = Dense(256, activation = 'relu')(fe1)

#sequence feature layers
inputs2 = Input(shape=(max_length,))
se1 = Embedding(vocab_size, 256, mask_zero = True)(inputs2)
se2 = Dropout(0.6)(se1) #increase dropout 0.6 to avoid overfitting
se3 = LSTM(256)(se2)

#decoder model
decoder1 = add([fe2, se3])
decoder2 = Dense(256, activation = 'relu')(decoder1)
outputs = Dense(vocab_size, activation = 'softmax')(decoder2)

final_model = Model(inputs=[inputs1, inputs2], outputs = outputs)

# plot the model
plot_model(final_model, show_shapes = True)

# %%
final_model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 35)]         0           []
#
#  input_1 (InputLayer)           [(None, 4096)]       0           []
#
#  embedding (Embedding)          (None, 35, 256)      2172160     ['input_2[0][0]']
#
#  dropout (Dropout)              (None, 4096)         0           ['input_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 35, 256)      0           ['embedding[0][0]']
#
#  dense (Dense)                  (None, 256)          1048832     ['dropout[0][0]']
#
#  lstm (LSTM)                    (None, 256)          525312      ['dropout_1[0][0]']
#
#  add (Add)                      (None, 256)          0           ['dense[0][0]',
#                                                                   'lstm[0][0]']
#
#  dense_1 (Dense)                (None, 256)          65792       ['add[0][0]']
#
#  dense_2 (Dense)                (None, 8485)         2180645     ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 5,992,741
# Trainable params: 5,992,741
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
#Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
final_model.compile(loss = 'categorical_crossentropy', optimizer = opt, metrics=['accuracy'])

# %%
# Train the model
epochs = 300
batch_size = 32
steps = len(train) // batch_size
val_steps = len(test) // batch_size

#Interrupts training when improvement stops and monitor the model's val acc
#Interrupts training when accuracy nas stopped improving for more than 5 epochs.
callbacks_list = tf.keras.callbacks.EarlyStopping(monitor = 'accuracy', patience = 5,)

#save results of model fit in a CSV file
csv_log = CSVLogger("base_vgg_dropout_results.csv")

# create data generator
generator = data_generator(train, mapping, features, tokenizer, max_length, vocab_size, batch_size)
val_generator = data_generator(val, mapping, features, tokenizer, max_length, vocab_size, batch_size)
#fit for one epoch
history = final_model.fit(generator, epochs = epochs, steps_per_epoch = steps, validation_data=val_generator, callbacks=(callbacks_list, csv_log), validation_steps=val_steps, verbose  = 1)
# Out:
# Epoch 1/300
# 190/190 [==============================] - 36s 150ms/step - loss: 5.3997 - accuracy: 0.1343 - val_loss: 4.5565 - val_accuracy: 0.1998
# Epoch 2/300
# 190/190 [==============================] - 27s 142ms/step - loss: 4.2129 - accuracy: 0.2311 - val_loss: 3.8472 - val_accuracy: 0.2641
# Epoch 3/300
# 190/190 [==============================] - 27s 141ms/step - loss: 3.7426 - accuracy: 0.2712 - val_loss: 3.5677 - val_accuracy: 0.2898
# Epoch 4/300
# 190/190 [==============================] - 27s 141ms/step - loss: 3.4684 - accuracy: 0.2915 - val_loss: 3.3875 - val_accuracy: 0.3058
# Epoch 5/300
# 190/190 [==============================] - 27s 141ms/step - loss: 3.2637 - accuracy: 0.3069 - val_loss: 3.2823 - val_accuracy: 0.3143
# Epoch 6/300
# 190/190 [==============================] - 27s 141ms/step - loss: 3.0998 - accuracy: 0.3203 - val_loss: 3.2073 - val_accuracy: 0.3218
# Epoch 7/300
# 190/190 [==============================] - 27s 142ms/step - loss: 2.9725 - accuracy: 0.3334 - val_loss: 3.1658 - val_accuracy: 0.3288
# Epoch 8/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.8680 - accuracy: 0.3455 - val_loss: 3.1237 - val_accuracy: 0.3358
# Epoch 9/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.7805 - accuracy: 0.3562 - val_loss: 3.0900 - val_accuracy: 0.3416
# Epoch 10/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.7055 - accuracy: 0.3662 - val_loss: 3.0590 - val_accuracy: 0.3465
# Epoch 11/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.6451 - accuracy: 0.3730 - val_loss: 3.0425 - val_accuracy: 0.3487
# Epoch 12/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.5901 - accuracy: 0.3804 - val_loss: 3.0139 - val_accuracy: 0.3535
# Epoch 13/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.5439 - accuracy: 0.3858 - val_loss: 2.9673 - val_accuracy: 0.3593
# Epoch 14/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.4984 - accuracy: 0.3937 - val_loss: 2.9346 - val_accuracy: 0.3650
# Epoch 15/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.4566 - accuracy: 0.3991 - val_loss: 2.9202 - val_accuracy: 0.3681
# Epoch 16/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.4199 - accuracy: 0.4036 - val_loss: 2.8921 - val_accuracy: 0.3732
# Epoch 17/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.3818 - accuracy: 0.4096 - val_loss: 2.8790 - val_accuracy: 0.3772
# Epoch 18/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.3484 - accuracy: 0.4146 - val_loss: 2.8605 - val_accuracy: 0.3835
# Epoch 19/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.3203 - accuracy: 0.4188 - val_loss: 2.8296 - val_accuracy: 0.3871
# Epoch 20/300
# 190/190 [==============================] - 26s 139ms/step - loss: 2.2927 - accuracy: 0.4233 - val_loss: 2.8429 - val_accuracy: 0.3873
# Epoch 21/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.2691 - accuracy: 0.4267 - val_loss: 2.8419 - val_accuracy: 0.3911
# Epoch 22/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.2437 - accuracy: 0.4313 - val_loss: 2.8431 - val_accuracy: 0.3915
# Epoch 23/300
# 190/190 [==============================] - 26s 139ms/step - loss: 2.2173 - accuracy: 0.4361 - val_loss: 2.8603 - val_accuracy: 0.3937
# Epoch 24/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.1969 - accuracy: 0.4389 - val_loss: 2.8586 - val_accuracy: 0.3927
# Epoch 25/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.1755 - accuracy: 0.4429 - val_loss: 2.8653 - val_accuracy: 0.3945
# Epoch 26/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.1574 - accuracy: 0.4456 - val_loss: 2.8613 - val_accuracy: 0.3957
# Epoch 27/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.1424 - accuracy: 0.4486 - val_loss: 2.8340 - val_accuracy: 0.4016
# Epoch 28/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.1255 - accuracy: 0.4499 - val_loss: 2.8218 - val_accuracy: 0.4040
# Epoch 29/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.1092 - accuracy: 0.4530 - val_loss: 2.8230 - val_accuracy: 0.4070
# Epoch 30/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.0918 - accuracy: 0.4565 - val_loss: 2.8574 - val_accuracy: 0.4055
# Epoch 31/300
# 190/190 [==============================] - 27s 141ms/step - loss: 2.0751 - accuracy: 0.4593 - val_loss: 2.8808 - val_accuracy: 0.4063
# Epoch 32/300
# 190/190 [==============================] - 26s 139ms/step - loss: 2.0608 - accuracy: 0.4623 - val_loss: 2.8085 - val_accuracy: 0.4128
# Epoch 33/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.0437 - accuracy: 0.4642 - val_loss: 2.7761 - val_accuracy: 0.4180
# Epoch 34/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.0326 - accuracy: 0.4671 - val_loss: 2.7267 - val_accuracy: 0.4256
# Epoch 35/300
# 190/190 [==============================] - 26s 139ms/step - loss: 2.0165 - accuracy: 0.4703 - val_loss: 2.7044 - val_accuracy: 0.4267
# Epoch 36/300
# 190/190 [==============================] - 27s 140ms/step - loss: 2.0048 - accuracy: 0.4719 - val_loss: 2.7160 - val_accuracy: 0.4296
# Epoch 37/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.9932 - accuracy: 0.4736 - val_loss: 2.7019 - val_accuracy: 0.4287
# Epoch 38/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.9820 - accuracy: 0.4760 - val_loss: 2.7184 - val_accuracy: 0.4304
# Epoch 39/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.9687 - accuracy: 0.4793 - val_loss: 2.7231 - val_accuracy: 0.4293
# Epoch 40/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.9570 - accuracy: 0.4799 - val_loss: 2.7424 - val_accuracy: 0.4285
# Epoch 41/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.9464 - accuracy: 0.4827 - val_loss: 2.7095 - val_accuracy: 0.4324
# Epoch 42/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.9392 - accuracy: 0.4840 - val_loss: 2.7099 - val_accuracy: 0.4363
# Epoch 43/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.9254 - accuracy: 0.4859 - val_loss: 2.6797 - val_accuracy: 0.4401
# Epoch 44/300
# 190/190 [==============================] - 27s 142ms/step - loss: 1.9149 - accuracy: 0.4886 - val_loss: 2.6941 - val_accuracy: 0.4380
# Epoch 45/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.9061 - accuracy: 0.4900 - val_loss: 2.6893 - val_accuracy: 0.4398
# Epoch 46/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.8978 - accuracy: 0.4916 - val_loss: 2.6855 - val_accuracy: 0.4407
# Epoch 47/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.8922 - accuracy: 0.4934 - val_loss: 2.6763 - val_accuracy: 0.4445
# Epoch 48/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.8826 - accuracy: 0.4949 - val_loss: 2.6822 - val_accuracy: 0.4466
# Epoch 49/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.8747 - accuracy: 0.4956 - val_loss: 2.6734 - val_accuracy: 0.4481
# Epoch 50/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.8689 - accuracy: 0.4971 - val_loss: 2.6386 - val_accuracy: 0.4520
# Epoch 51/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.8609 - accuracy: 0.4990 - val_loss: 2.6365 - val_accuracy: 0.4536
# Epoch 52/300
# 190/190 [==============================] - 27s 142ms/step - loss: 1.8523 - accuracy: 0.4999 - val_loss: 2.6215 - val_accuracy: 0.4539
# Epoch 53/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.8441 - accuracy: 0.5017 - val_loss: 2.6314 - val_accuracy: 0.4550
# Epoch 54/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.8373 - accuracy: 0.5030 - val_loss: 2.6226 - val_accuracy: 0.4575
# Epoch 55/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.8267 - accuracy: 0.5054 - val_loss: 2.6248 - val_accuracy: 0.4581
# Epoch 56/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.8238 - accuracy: 0.5059 - val_loss: 2.6355 - val_accuracy: 0.4566
# Epoch 57/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.8172 - accuracy: 0.5073 - val_loss: 2.6496 - val_accuracy: 0.4567
# Epoch 58/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.8096 - accuracy: 0.5085 - val_loss: 2.6296 - val_accuracy: 0.4612
# Epoch 59/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.8004 - accuracy: 0.5107 - val_loss: 2.6195 - val_accuracy: 0.4600
# Epoch 60/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.7951 - accuracy: 0.5105 - val_loss: 2.6354 - val_accuracy: 0.4611
# Epoch 61/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.7868 - accuracy: 0.5135 - val_loss: 2.6328 - val_accuracy: 0.4606
# Epoch 62/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.7788 - accuracy: 0.5150 - val_loss: 2.6242 - val_accuracy: 0.4625
# Epoch 63/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.7744 - accuracy: 0.5149 - val_loss: 2.6221 - val_accuracy: 0.4652
# Epoch 64/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.7684 - accuracy: 0.5165 - val_loss: 2.6283 - val_accuracy: 0.4649
# Epoch 65/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.7615 - accuracy: 0.5183 - val_loss: 2.6160 - val_accuracy: 0.4686
# Epoch 66/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.7556 - accuracy: 0.5196 - val_loss: 2.6099 - val_accuracy: 0.4695
# Epoch 67/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.7498 - accuracy: 0.5202 - val_loss: 2.6097 - val_accuracy: 0.4709
# Epoch 68/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.7459 - accuracy: 0.5221 - val_loss: 2.6051 - val_accuracy: 0.4720
# Epoch 69/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.7370 - accuracy: 0.5227 - val_loss: 2.6210 - val_accuracy: 0.4712
# Epoch 70/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.7327 - accuracy: 0.5242 - val_loss: 2.6116 - val_accuracy: 0.4753
# Epoch 71/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.7247 - accuracy: 0.5249 - val_loss: 2.6141 - val_accuracy: 0.4746
# Epoch 72/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.7204 - accuracy: 0.5271 - val_loss: 2.6231 - val_accuracy: 0.4739
# Epoch 73/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.7160 - accuracy: 0.5265 - val_loss: 2.6284 - val_accuracy: 0.4737
# Epoch 74/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.7088 - accuracy: 0.5293 - val_loss: 2.6241 - val_accuracy: 0.4744
# Epoch 75/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.7032 - accuracy: 0.5303 - val_loss: 2.6323 - val_accuracy: 0.4776
# Epoch 76/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.6980 - accuracy: 0.5318 - val_loss: 2.6372 - val_accuracy: 0.4764
# Epoch 77/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.6950 - accuracy: 0.5325 - val_loss: 2.6230 - val_accuracy: 0.4800
# Epoch 78/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.6870 - accuracy: 0.5321 - val_loss: 2.5997 - val_accuracy: 0.4786
# Epoch 79/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.6814 - accuracy: 0.5336 - val_loss: 2.6330 - val_accuracy: 0.4792
# Epoch 80/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.6758 - accuracy: 0.5350 - val_loss: 2.6433 - val_accuracy: 0.4780
# Epoch 81/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.6717 - accuracy: 0.5370 - val_loss: 2.6396 - val_accuracy: 0.4806
# Epoch 82/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.6691 - accuracy: 0.5361 - val_loss: 2.6365 - val_accuracy: 0.4846
# Epoch 83/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.6602 - accuracy: 0.5392 - val_loss: 2.6360 - val_accuracy: 0.4840
# Epoch 84/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.6561 - accuracy: 0.5405 - val_loss: 2.6426 - val_accuracy: 0.4844
# Epoch 85/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.6491 - accuracy: 0.5408 - val_loss: 2.6404 - val_accuracy: 0.4853
# Epoch 86/300
# 190/190 [==============================] - 27s 142ms/step - loss: 1.6475 - accuracy: 0.5407 - val_loss: 2.6371 - val_accuracy: 0.4872
# Epoch 87/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.6422 - accuracy: 0.5433 - val_loss: 2.6428 - val_accuracy: 0.4873
# Epoch 88/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.6368 - accuracy: 0.5443 - val_loss: 2.6560 - val_accuracy: 0.4871
# Epoch 89/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.6354 - accuracy: 0.5438 - val_loss: 2.6482 - val_accuracy: 0.4897
# Epoch 90/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.6307 - accuracy: 0.5450 - val_loss: 2.6402 - val_accuracy: 0.4908
# Epoch 91/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.6251 - accuracy: 0.5467 - val_loss: 2.6271 - val_accuracy: 0.4919
# Epoch 92/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.6247 - accuracy: 0.5462 - val_loss: 2.6507 - val_accuracy: 0.4936
# Epoch 93/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.6208 - accuracy: 0.5468 - val_loss: 2.6296 - val_accuracy: 0.4939
# Epoch 94/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.6131 - accuracy: 0.5482 - val_loss: 2.6240 - val_accuracy: 0.4970
# Epoch 95/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.6103 - accuracy: 0.5489 - val_loss: 2.6211 - val_accuracy: 0.4980
# Epoch 96/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.6081 - accuracy: 0.5494 - val_loss: 2.6332 - val_accuracy: 0.4962
# Epoch 97/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.6034 - accuracy: 0.5515 - val_loss: 2.6258 - val_accuracy: 0.4979
# Epoch 98/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.6011 - accuracy: 0.5510 - val_loss: 2.6249 - val_accuracy: 0.4979
# Epoch 99/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.5953 - accuracy: 0.5525 - val_loss: 2.6299 - val_accuracy: 0.5001
# Epoch 100/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5959 - accuracy: 0.5508 - val_loss: 2.6262 - val_accuracy: 0.5000
# Epoch 101/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.5907 - accuracy: 0.5531 - val_loss: 2.6294 - val_accuracy: 0.5012
# Epoch 102/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.5835 - accuracy: 0.5553 - val_loss: 2.6362 - val_accuracy: 0.5011
# Epoch 103/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5826 - accuracy: 0.5539 - val_loss: 2.6328 - val_accuracy: 0.5032
# Epoch 104/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.5793 - accuracy: 0.5565 - val_loss: 2.6207 - val_accuracy: 0.5054
# Epoch 105/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5793 - accuracy: 0.5553 - val_loss: 2.6464 - val_accuracy: 0.5041
# Epoch 106/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.5740 - accuracy: 0.5569 - val_loss: 2.6077 - val_accuracy: 0.5085
# Epoch 107/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5716 - accuracy: 0.5584 - val_loss: 2.6268 - val_accuracy: 0.5070
# Epoch 108/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5707 - accuracy: 0.5573 - val_loss: 2.6042 - val_accuracy: 0.5076
# Epoch 109/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5671 - accuracy: 0.5584 - val_loss: 2.6387 - val_accuracy: 0.5065
# Epoch 110/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5675 - accuracy: 0.5579 - val_loss: 2.6090 - val_accuracy: 0.5114
# Epoch 111/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5617 - accuracy: 0.5595 - val_loss: 2.6278 - val_accuracy: 0.5111
# Epoch 112/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5594 - accuracy: 0.5603 - val_loss: 2.6179 - val_accuracy: 0.5125
# Epoch 113/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.5570 - accuracy: 0.5606 - val_loss: 2.6326 - val_accuracy: 0.5143
# Epoch 114/300
# 190/190 [==============================] - 27s 142ms/step - loss: 1.5525 - accuracy: 0.5614 - val_loss: 2.6374 - val_accuracy: 0.5109
# Epoch 115/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.5506 - accuracy: 0.5620 - val_loss: 2.6124 - val_accuracy: 0.5139
# Epoch 116/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5492 - accuracy: 0.5623 - val_loss: 2.6180 - val_accuracy: 0.5166
# Epoch 117/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.5448 - accuracy: 0.5638 - val_loss: 2.6321 - val_accuracy: 0.5135
# Epoch 118/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5406 - accuracy: 0.5633 - val_loss: 2.6002 - val_accuracy: 0.5188
# Epoch 119/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5402 - accuracy: 0.5648 - val_loss: 2.6178 - val_accuracy: 0.5161
# Epoch 120/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5396 - accuracy: 0.5645 - val_loss: 2.6034 - val_accuracy: 0.5193
# Epoch 121/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5341 - accuracy: 0.5645 - val_loss: 2.6008 - val_accuracy: 0.5180
# Epoch 122/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.5344 - accuracy: 0.5648 - val_loss: 2.5913 - val_accuracy: 0.5209
# Epoch 123/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.5310 - accuracy: 0.5653 - val_loss: 2.5942 - val_accuracy: 0.5198
# Epoch 124/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.5288 - accuracy: 0.5664 - val_loss: 2.5923 - val_accuracy: 0.5217
# Epoch 125/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5283 - accuracy: 0.5664 - val_loss: 2.5859 - val_accuracy: 0.5203
# Epoch 126/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.5249 - accuracy: 0.5676 - val_loss: 2.5815 - val_accuracy: 0.5232
# Epoch 127/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5216 - accuracy: 0.5683 - val_loss: 2.6180 - val_accuracy: 0.5198
# Epoch 128/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.5188 - accuracy: 0.5686 - val_loss: 2.5883 - val_accuracy: 0.5225
# Epoch 129/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5170 - accuracy: 0.5681 - val_loss: 2.5777 - val_accuracy: 0.5247
# Epoch 130/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.5116 - accuracy: 0.5692 - val_loss: 2.6015 - val_accuracy: 0.5238
# Epoch 131/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5101 - accuracy: 0.5708 - val_loss: 2.5844 - val_accuracy: 0.5242
# Epoch 132/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5117 - accuracy: 0.5698 - val_loss: 2.5715 - val_accuracy: 0.5280
# Epoch 133/300
# 190/190 [==============================] - 27s 142ms/step - loss: 1.5071 - accuracy: 0.5709 - val_loss: 2.5989 - val_accuracy: 0.5252
# Epoch 134/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5063 - accuracy: 0.5716 - val_loss: 2.5712 - val_accuracy: 0.5286
# Epoch 135/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.5049 - accuracy: 0.5706 - val_loss: 2.5773 - val_accuracy: 0.5296
# Epoch 136/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5016 - accuracy: 0.5714 - val_loss: 2.5842 - val_accuracy: 0.5272
# Epoch 137/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.5012 - accuracy: 0.5718 - val_loss: 2.5922 - val_accuracy: 0.5283
# Epoch 138/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4975 - accuracy: 0.5741 - val_loss: 2.5587 - val_accuracy: 0.5274
# Epoch 139/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.4936 - accuracy: 0.5738 - val_loss: 2.6037 - val_accuracy: 0.5308
# Epoch 140/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4932 - accuracy: 0.5736 - val_loss: 2.6000 - val_accuracy: 0.5251
# Epoch 141/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.4903 - accuracy: 0.5743 - val_loss: 2.5874 - val_accuracy: 0.5277
# Epoch 142/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4881 - accuracy: 0.5749 - val_loss: 2.5977 - val_accuracy: 0.5293
# Epoch 143/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4888 - accuracy: 0.5745 - val_loss: 2.6071 - val_accuracy: 0.5268
# Epoch 144/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.4829 - accuracy: 0.5756 - val_loss: 2.6257 - val_accuracy: 0.5267
# Epoch 145/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.4856 - accuracy: 0.5759 - val_loss: 2.6136 - val_accuracy: 0.5284
# Epoch 146/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4802 - accuracy: 0.5769 - val_loss: 2.6193 - val_accuracy: 0.5301
# Epoch 147/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4795 - accuracy: 0.5770 - val_loss: 2.6389 - val_accuracy: 0.5297
# Epoch 148/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.4795 - accuracy: 0.5778 - val_loss: 2.6243 - val_accuracy: 0.5302
# Epoch 149/300
# 190/190 [==============================] - 26s 140ms/step - loss: 1.4786 - accuracy: 0.5775 - val_loss: 2.6195 - val_accuracy: 0.5312
# Epoch 150/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4760 - accuracy: 0.5766 - val_loss: 2.6250 - val_accuracy: 0.5336
# Epoch 151/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4733 - accuracy: 0.5785 - val_loss: 2.6056 - val_accuracy: 0.5353
# Epoch 152/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.4699 - accuracy: 0.5791 - val_loss: 2.5941 - val_accuracy: 0.5349
# Epoch 153/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4670 - accuracy: 0.5794 - val_loss: 2.6310 - val_accuracy: 0.5327
# Epoch 154/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.4680 - accuracy: 0.5785 - val_loss: 2.6170 - val_accuracy: 0.5329
# Epoch 155/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4640 - accuracy: 0.5797 - val_loss: 2.6190 - val_accuracy: 0.5344
# Epoch 156/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4635 - accuracy: 0.5805 - val_loss: 2.6104 - val_accuracy: 0.5338
# Epoch 157/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.4603 - accuracy: 0.5816 - val_loss: 2.6464 - val_accuracy: 0.5315
# Epoch 158/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.4579 - accuracy: 0.5821 - val_loss: 2.6409 - val_accuracy: 0.5345
# Epoch 159/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4565 - accuracy: 0.5814 - val_loss: 2.6220 - val_accuracy: 0.5352
# Epoch 160/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.4579 - accuracy: 0.5820 - val_loss: 2.5891 - val_accuracy: 0.5393
# Epoch 161/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4543 - accuracy: 0.5813 - val_loss: 2.6166 - val_accuracy: 0.5367
# Epoch 162/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4541 - accuracy: 0.5837 - val_loss: 2.6085 - val_accuracy: 0.5401
# Epoch 163/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4528 - accuracy: 0.5826 - val_loss: 2.6155 - val_accuracy: 0.5385
# Epoch 164/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4530 - accuracy: 0.5826 - val_loss: 2.6317 - val_accuracy: 0.5368
# Epoch 165/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.4486 - accuracy: 0.5837 - val_loss: 2.6128 - val_accuracy: 0.5404
# Epoch 166/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4505 - accuracy: 0.5838 - val_loss: 2.6042 - val_accuracy: 0.5411
# Epoch 167/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4448 - accuracy: 0.5837 - val_loss: 2.6148 - val_accuracy: 0.5406
# Epoch 168/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.4453 - accuracy: 0.5844 - val_loss: 2.6192 - val_accuracy: 0.5405
# Epoch 169/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4437 - accuracy: 0.5843 - val_loss: 2.6154 - val_accuracy: 0.5408
# Epoch 170/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.4430 - accuracy: 0.5848 - val_loss: 2.5965 - val_accuracy: 0.5448
# Epoch 171/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4372 - accuracy: 0.5862 - val_loss: 2.6010 - val_accuracy: 0.5422
# Epoch 172/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4390 - accuracy: 0.5858 - val_loss: 2.5794 - val_accuracy: 0.5458
# Epoch 173/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4351 - accuracy: 0.5876 - val_loss: 2.5889 - val_accuracy: 0.5436
# Epoch 174/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.4386 - accuracy: 0.5864 - val_loss: 2.6004 - val_accuracy: 0.5435
# Epoch 175/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4337 - accuracy: 0.5872 - val_loss: 2.6112 - val_accuracy: 0.5438
# Epoch 176/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.4324 - accuracy: 0.5883 - val_loss: 2.6311 - val_accuracy: 0.5417
# Epoch 177/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4283 - accuracy: 0.5878 - val_loss: 2.6133 - val_accuracy: 0.5426
# Epoch 178/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4288 - accuracy: 0.5877 - val_loss: 2.6175 - val_accuracy: 0.5432
# Epoch 179/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.4262 - accuracy: 0.5886 - val_loss: 2.6029 - val_accuracy: 0.5460
# Epoch 180/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.4283 - accuracy: 0.5886 - val_loss: 2.5960 - val_accuracy: 0.5451
# Epoch 181/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4249 - accuracy: 0.5890 - val_loss: 2.6163 - val_accuracy: 0.5452
# Epoch 182/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.4238 - accuracy: 0.5892 - val_loss: 2.6228 - val_accuracy: 0.5452
# Epoch 183/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.4264 - accuracy: 0.5881 - val_loss: 2.5700 - val_accuracy: 0.5496
# Epoch 184/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.4271 - accuracy: 0.5879 - val_loss: 2.5595 - val_accuracy: 0.5497
# Epoch 185/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4255 - accuracy: 0.5885 - val_loss: 2.5871 - val_accuracy: 0.5490
# Epoch 186/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.4247 - accuracy: 0.5882 - val_loss: 2.5768 - val_accuracy: 0.5481
# Epoch 187/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.4198 - accuracy: 0.5901 - val_loss: 2.5726 - val_accuracy: 0.5512
# Epoch 188/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.4231 - accuracy: 0.5901 - val_loss: 2.5862 - val_accuracy: 0.5501
# Epoch 189/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4146 - accuracy: 0.5911 - val_loss: 2.6081 - val_accuracy: 0.5496
# Epoch 190/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.4131 - accuracy: 0.5901 - val_loss: 2.6102 - val_accuracy: 0.5487
# Epoch 191/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4147 - accuracy: 0.5916 - val_loss: 2.6088 - val_accuracy: 0.5491
# Epoch 192/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4170 - accuracy: 0.5894 - val_loss: 2.5886 - val_accuracy: 0.5525
# Epoch 193/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.4145 - accuracy: 0.5910 - val_loss: 2.5830 - val_accuracy: 0.5535
# Epoch 194/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.4127 - accuracy: 0.5917 - val_loss: 2.5956 - val_accuracy: 0.5562
# Epoch 195/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4140 - accuracy: 0.5917 - val_loss: 2.6148 - val_accuracy: 0.5512
# Epoch 196/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4141 - accuracy: 0.5914 - val_loss: 2.6050 - val_accuracy: 0.5538
# Epoch 197/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.4119 - accuracy: 0.5919 - val_loss: 2.6263 - val_accuracy: 0.5508
# Epoch 198/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4133 - accuracy: 0.5914 - val_loss: 2.6364 - val_accuracy: 0.5508
# Epoch 199/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.4080 - accuracy: 0.5933 - val_loss: 2.6423 - val_accuracy: 0.5533
# Epoch 200/300
# 190/190 [==============================] - 26s 139ms/step - loss: 1.4068 - accuracy: 0.5928 - val_loss: 2.6586 - val_accuracy: 0.5496
# Epoch 201/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4074 - accuracy: 0.5929 - val_loss: 2.6340 - val_accuracy: 0.5518
# Epoch 202/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4082 - accuracy: 0.5925 - val_loss: 2.6322 - val_accuracy: 0.5536
# Epoch 203/300
# 190/190 [==============================] - 27s 141ms/step - loss: 1.4082 - accuracy: 0.5928 - val_loss: 2.6206 - val_accuracy: 0.5549
# Epoch 204/300
# 190/190 [==============================] - 27s 140ms/step - loss: 1.4060 - accuracy: 0.5928 - val_loss: 2.6335 - val_accuracy: 0.5556

# %%
# save the model
final_model.save(WORKING_DIR + '/base_val_vgg_dropout_model.h5')

# %% [markdown]
# ### Visualizing Model Accuracy and Loss

# %%
#load CSV file
data = pd.read_csv(mount + "/My Drive/Colab Notebooks/Capstone/Code/base_vgg_dropout_results.csv")
data.head()
# Out:
#    epoch  accuracy      loss  val_accuracy  val_loss
# 0      0  0.134320  5.399709      0.199832  4.556497
# 1      1  0.231111  4.212877      0.264131  3.847220
# 2      2  0.271245  3.742627      0.289762  3.567747
# 3      3  0.291527  3.468371      0.305752  3.387478
# 4      4  0.306938  3.263725      0.314297  3.282314

# %%
# Plot Training/Val Accuracy/Loss by Epoch for Base VGG16 plus Dropout Model
plt.title('Training/Val Accuracy/Loss by Epoch (Base VGG16 plus Dropout Model)', fontsize = 25)
plt.plot(data['accuracy'], color='blue', label='accuracy')
plt.plot(data['loss'], color='orange', label='loss')
plt.plot(data['val_loss'], color='green', label='val_loss')
plt.plot(data['val_accuracy'], color='red', label='val_accuracy')
plt.xlabel('Epoch', fontsize = 18)
plt.ylabel('Categorical Crossentropy', fontsize = 18)
plt.rcParams["figure.figsize"] = (15,10)
plt.legend()
plt.show()

# %% [markdown]
# ## Generate Captions for Images

# %%
def idx_to_word(integer, tokenizer):
    for word, index in tokenizer.word_index.items():
        if index == integer:
            return word
    return None

# %%
# generate caption for an image
def predict_caption(model, image, tokenizer, max_length):
    #add start tag for generation process
    in_text = 'startseq'
    #iterate over the max length of sequence
    for i in range(max_length):
        #encode input sequence
        sequence = tokenizer.texts_to_sequences([in_text])[0]
        #pad the sequence
        sequence = pad_sequences([sequence], max_length)
        #predict next word
        yhat = final_model.predict([image, sequence], verbose = 0)
        #get index with high probability
        yhat= np.argmax(yhat)
        #convert index to word
        word = idx_to_word(yhat, tokenizer)
        #stop if word not found
        if word is None:
            break
        #append word as input for generation next word
        in_text += ' ' + word
        #stop if we reach end tag
        if word == 'endseq':
            break
    return in_text

# %% [markdown]
# ### BLEU Score

# %%
from nltk.translate.bleu_score import corpus_bleu

# %%
# validate with test data
actual, predicted = list(), list()

for key in tqdm(test):
    #get actual caption
    captions = mapping[key]
    #predict the caption for image
    y_pred = predict_caption(final_model, features[key], tokenizer, max_length)
    #split into words  
    actual_captions = [caption.split() for caption in captions]
    y_pred = y_pred.split()
    #append to the list
    actual.append(actual_captions)
    predicted.append(y_pred)
    
#calculate BLEU Score
print("BLEU-1: %f" % corpus_bleu(actual, predicted, weights = (1.0, 0, 0, 0)))
print("BLEU-2: %f" % corpus_bleu(actual, predicted, weights = (0.5, 0.5, 0, 0)))
print("BLEU-3: %f" % corpus_bleu(actual, predicted, weights = (0.3, 0.3, 0.3, 0.1)))
print("BLEU-4: %f" % corpus_bleu(actual, predicted, weights = (0.25, 0.25, 0.25, 0.25)))
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# BLEU-1: 0.636441
# BLEU-2: 0.449120
# BLEU-3: 0.304578
# BLEU-4: 0.261126

# %% [markdown]
# ## Visualize the Results of Image Captions

# %%
from PIL import Image
import matplotlib.pyplot as plt

def generate_caption(image_name):
    #load the image
    image_id = image_name.split('.')[0]
    img_path = os.path.join(BASE_DIR, "Images", image_name)
    image = Image.open(img_path)
    captions = mapping[image_id]
    print('-----------Actual-----------')
    for caption in captions:
        print(caption)

    #predict the caption
    y_pred = predict_caption(final_model, features[image_id], tokenizer, max_length)
    print('-----------Predicted-----------')
    print(y_pred)
    plt.imshow(image)

# %%
generate_caption("421808539_57abee6d55.jpg")
# Out:
# -----------Actual-----------
# startseq brown dog walks through snow endseq
# startseq brown puppy walking through the snow endseq
# startseq dog looks curious at adventures lying ahead in the snow endseq
# startseq dog walking in the snow endseq
# startseq yellow puppy walking through the snow endseq
# -----------Predicted-----------
# startseq brown dog is walking through the snow endseq

# %%
generate_caption("1193116658_c0161c35b5.jpg")
# Out:
# -----------Actual-----------
# startseq girl rides unicycle as another rides scooter next to her endseq
# startseq girl rides unicycle with child who rides scooter endseq
# startseq young girl rides unicycle next to another riding scooter on busy street endseq
# startseq the girl on the unicycle reaches out for the child on the scooter endseq
# startseq there is girl on unicycle and child on scooter endseq
# -----------Predicted-----------
# startseq woman in purple and white walks down the street endseq

# %%
generate_caption("1285067106_2adc307240.jpg")
# Out:
# -----------Actual-----------
# startseq boy in white plays baseball endseq
# startseq young boy is getting ready to through baseball endseq
# startseq little leaguer getting ready for pitch endseq
# startseq the boy is wearing white baseball uniform and holding baseball endseq
# startseq the young ohio baseball player contemplates his pitch endseq
# -----------Predicted-----------
# startseq man in white shirt is holding baseball while the man in the grey shirt walks endseq

# %%
generate_caption("516725192_c9cdd63878.jpg")
# Out:
# -----------Actual-----------
# startseq fisherman stands on the beach on gray day endseq
# startseq man holding fishing pole and tackle box walking in from the ocean endseq
# startseq man in yellow cap is on the beach carrying fishing pole endseq
# startseq man with fishing pole standing on beach endseq
# startseq person is standing in the ocean fully clothed holding fishing pole in one hand and tackle box in the other endseq
# -----------Predicted-----------
# startseq man is standing on rope in the ocean endseq
